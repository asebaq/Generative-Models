# %%
# !nvidia-smi
# Out:
# Tue Feb 28 11:20:29 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 520.61.05    Driver Version: 520.61.05    CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:01:00.0 Off |                  N/A |
# | N/A   47C    P8    18W /  N/A |     10MiB /  8192MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1807      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A      3178      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Instal apex if you want to do 16 bit training. You'll probably need to restart the notebook after installing apex

# %%
# !export CUDA_HOME=/usr/local/cuda-10.1
# !git clone https://github.com/NVIDIA/apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex

# %%
# !pip install transformers
# !pip install pytorch_lightning
# Out:
# Requirement already satisfied: transformers in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (4.26.0)
# Requirement already satisfied: filelock in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: requests in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: tqdm>=4.27 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (1.24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers) (0.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->transformers) (3.4)
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pytorch_lightning in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (1.9.2)
# Requirement already satisfied: torch>=1.10.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (1.13.0+cu117)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (0.6.0.post0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (2023.1.0)
# Requirement already satisfied: numpy>=1.17.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (1.24.2)
# Requirement already satisfied: packaging>=17.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (23.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (0.11.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (4.4.0)
# Requirement already satisfied: PyYAML>=5.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: tqdm>=4.57.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch_lightning) (4.64.1)
# Requirement already satisfied: requests in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.28.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (3.8.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2022.12.7)
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install -r ../requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117, https://download.pytorch.org/whl/cu117
# Requirement already satisfied: einops in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: tqdm in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 2)) (4.64.1)
# Requirement already satisfied: pillow in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: numpy in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 4)) (1.24.2)
# Requirement already satisfied: matplotlib in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 5)) (3.6.3)
# Requirement already satisfied: torch==1.13.0+cu117 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 7)) (1.13.0+cu117)
# Requirement already satisfied: torchvision==0.14.0+cu117 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 9)) (0.14.0+cu117)
# Requirement already satisfied: autopep8 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: jupyter in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: tensorboard in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 13)) (2.11.2)
# Requirement already satisfied: opencv-python in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 14)) (4.7.0.68)
# Requirement already satisfied: tensorflow in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 15)) (2.11.0)
# Requirement already satisfied: torchmetrics[image] in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 16)) (0.11.1)
# Requirement already satisfied: torchsummary in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: pandas in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 18)) (1.5.3)
# Requirement already satisfied: transformers in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 19)) (4.26.0)
# Requirement already satisfied: pytorch-transformers in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 20)) (1.2.0)
# Requirement already satisfied: imutils in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 21)) (0.5.4)
# Requirement already satisfied: pylint in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 22)) (2.16.1)
# Requirement already satisfied: imagen-pytorch in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 24)) (1.22.1)
# Requirement already satisfied: lion-pytorch in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 25)) (0.0.6)
# Requirement already satisfied: nltk in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 26)) (3.8.1)
# Requirement already satisfied: typing-extensions in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torch==1.13.0+cu117->-r ../requirements.txt (line 7)) (4.4.0)
# Requirement already satisfied: requests in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (2.28.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: pycodestyle>=2.10.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from autopep8->-r ../requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: tomli in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from autopep8->-r ../requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: jupyter-console in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (6.4.4)
# Requirement already satisfied: ipykernel in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (6.21.1)
# Requirement already satisfied: qtconsole in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (5.4.0)
# Requirement already satisfied: ipywidgets in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (8.0.4)
# Requirement already satisfied: nbconvert in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (7.2.9)
# Requirement already satisfied: notebook in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (6.5.2)
# Requirement already satisfied: wheel>=0.26 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (2.16.0)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (3.19.6)
# Requirement already satisfied: setuptools>=41.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (65.5.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (1.51.1)
# Requirement already satisfied: absl-py>=0.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (0.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (2.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (3.8.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (0.30.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (23.1.21)
# Requirement already satisfied: astunparse>=1.6.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (15.0.6.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (1.14.1)
# Requirement already satisfied: scipy in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torchmetrics[image]->-r ../requirements.txt (line 16)) (1.10.0)
# Requirement already satisfied: torch-fidelity in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torchmetrics[image]->-r ../requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: lpips in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torchmetrics[image]->-r ../requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: pytz>=2020.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pandas->-r ../requirements.txt (line 18)) (2022.7.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (0.12.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (0.13.2)
# Requirement already satisfied: filelock in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (3.9.0)
# Requirement already satisfied: sacremoses in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch-transformers->-r ../requirements.txt (line 20)) (0.0.53)
# Requirement already satisfied: boto3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch-transformers->-r ../requirements.txt (line 20)) (1.26.67)
# Requirement already satisfied: sentencepiece in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch-transformers->-r ../requirements.txt (line 20)) (0.1.97)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (0.7.0)
# Requirement already satisfied: isort<6,>=4.2.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (5.12.0)
# Requirement already satisfied: astroid<=2.16.0-dev0,>=2.14.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (2.14.1)
# Requirement already satisfied: dill>=0.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (0.3.6)
# Requirement already satisfied: platformdirs>=2.2.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (3.0.0)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (0.11.6)
# Requirement already satisfied: datasets in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (2.9.0)
# Requirement already satisfied: triton in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (1.1.1)
# Requirement already satisfied: beartype in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.12.0)
# Requirement already satisfied: pytorch-warmup in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.1.1)
# Requirement already satisfied: fsspec in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (2023.1.0)
# Requirement already satisfied: kornia in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.6.9)
# Requirement already satisfied: pydantic in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (1.10.5)
# Requirement already satisfied: click in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (8.1.3)
# Requirement already satisfied: ema-pytorch>=0.0.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.2.1)
# Requirement already satisfied: accelerate in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.16.0)
# Requirement already satisfied: pytorch-lightning in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (1.9.2)
# Requirement already satisfied: einops-exts in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.0.4)
# Requirement already satisfied: joblib in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nltk->-r ../requirements.txt (line 26)) (1.2.0)
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from astroid<=2.16.0-dev0,>=2.14.1->pylint->-r ../requirements.txt (line 22)) (1.9.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r ../requirements.txt (line 13)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r ../requirements.txt (line 13)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r ../requirements.txt (line 13)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r ../requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard->-r ../requirements.txt (line 13)) (6.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard->-r ../requirements.txt (line 13)) (2.1.2)
# Requirement already satisfied: psutil in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from accelerate->imagen-pytorch->-r ../requirements.txt (line 24)) (5.9.4)
# Requirement already satisfied: botocore<1.30.0,>=1.29.67 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r ../requirements.txt (line 20)) (1.29.67)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r ../requirements.txt (line 20)) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r ../requirements.txt (line 20)) (1.0.1)
# Requirement already satisfied: aiohttp in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (3.8.4)
# Requirement already satisfied: multiprocess in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (0.70.14)
# Requirement already satisfied: responses<0.19 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (0.18.0)
# Requirement already satisfied: xxhash in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (3.2.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (11.0.0)
# Requirement already satisfied: ipython>=7.23.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (8.9.0)
# Requirement already satisfied: comm>=0.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: tornado>=6.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (6.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (8.0.2)
# Requirement already satisfied: nest-asyncio in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (1.5.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (5.2.0)
# Requirement already satisfied: pyzmq>=17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (25.0.0)
# Requirement already satisfied: traitlets>=5.4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.1.6)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 12)) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 12)) (3.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-console->jupyter->-r ../requirements.txt (line 12)) (3.0.36)
# Requirement already satisfied: pygments in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-console->jupyter->-r ../requirements.txt (line 12)) (2.14.0)
# Requirement already satisfied: bleach in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: nbformat>=5.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (5.7.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (4.11.2)
# Requirement already satisfied: tinycss2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.7.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (2.0.5)
# Requirement already satisfied: defusedxml in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: prometheus-client in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: argon2-cffi in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (21.3.0)
# Requirement already satisfied: ipython-genutils in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch-lightning->imagen-pytorch->-r ../requirements.txt (line 24)) (0.6.0.post0)
# Requirement already satisfied: qtpy>=2.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from qtconsole->jupyter->-r ../requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r ../requirements.txt (line 13)) (3.12.1)
# Requirement already satisfied: jedi>=0.16 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (4.8.0)
# Requirement already satisfied: pickleshare in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.7.5)
# Requirement already satisfied: decorator in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: backcall in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: stack-data in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.6.2)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (4.17.3)
# Requirement already satisfied: fastjsonschema in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (2.16.2)
# Requirement already satisfied: wcwidth in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->-r ../requirements.txt (line 12)) (0.2.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r ../requirements.txt (line 13)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r ../requirements.txt (line 13)) (3.2.2)
# Requirement already satisfied: ptyprocess in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->jupyter->-r ../requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->-r ../requirements.txt (line 12)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 12)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.19.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (5.10.2)
# Requirement already satisfied: jupyter-server-terminals in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.4.4)
# Requirement already satisfied: jupyter-events>=0.4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.6.3)
# Requirement already satisfied: anyio>=3.1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (3.6.2)
# Requirement already satisfied: websocket-client in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r ../requirements.txt (line 12)) (1.15.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: pure-eval in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: pycparser in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r ../requirements.txt (line 12)) (2.21)
# Requirement already satisfied: rfc3339-validator in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.1.1)
# Requirement already satisfied: fqdn in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: isoduration in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.12)
# Requirement already satisfied: jsonpointer>1.13 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (2.3)
# Requirement already satisfied: uri-template in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: arrow>=0.15.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.2.3)
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## T5 fine-tuning
#
# This notebook is to showcase how to fine-tune [T5 model](https://arxiv.org/abs/1910.10683) with Huggigface's [Transformers](https://github.com/huggingface/transformers/) to solve different NLP tasks using text-2-text approach proposed in the T5 paper. For demo I chose 3 non text-2-text problems just to reiterate the fact from the paper that how widely applicable this text-2-text framework is and how it can be used for different tasks without changing the model at all.
#
# This is a rough draft so if you find any issues with this notebook or have any  questions reach out to me via [Twitter](https://twitter.com/psuraj28).

# %%
import argparse
import glob
import os
import json
import time
import logging
import random
import re
from itertools import chain
from string import punctuation

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl


from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)
# Out:
# [nltk_data] Downloading package punkt to /home/asebaq/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2023-02-28 11:20:38.385688: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 11:20:39.276765: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-28 11:20:39.276917: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-28 11:20:39.276925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)

# %% [markdown]
# ## Model
#
# We'll be using the awesome [pytorch-lightning](https://github.com/PytorchLightning/pytorch-lightning) library for training. Most of the below code is adapted from here https://github.com/huggingface/transformers/blob/master/examples/lightning_base.py
#
# The trainer is generic and can be used for any text-2-text task. You'll just need to change the dataset. Rest of the code will stay unchanged for all the tasks.
#
# This is the most intresting and powrfull thing about the text-2-text format. You can fine-tune the model on variety of NLP tasks by just formulating the problem in text-2-text setting. No need to change hyperparameters, learning rate, optimizer or loss function. Just plug in your dataset and you are ready to go!

# %%
class T5FineTuner(pl.LightningModule):
    def __init__(self, hparams):
        super(T5FineTuner, self).__init__()
        # self.hparams = hparams
        self.hparams.update(vars(hparams))

        self.model = T5ForConditionalGeneration.from_pretrained(hparams.model_name_or_path)
        self.tokenizer = T5Tokenizer.from_pretrained(hparams.tokenizer_name_or_path)
  
    def is_logger(self):
        return self.trainer.global_rank <= 0
  
    def forward(
      self, input_ids, attention_mask=None, decoder_input_ids=None, decoder_attention_mask=None, labels=None
    ):
        return self.model(
            input_ids,
            attention_mask=attention_mask,
            decoder_input_ids=decoder_input_ids,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels,
        )

    def _step(self, batch):
        labels = batch["target_ids"]
        labels[labels[:, :] == self.tokenizer.pad_token_id] = -100

        outputs = self(
            input_ids=batch["source_ids"],
            attention_mask=batch["source_mask"],
            labels=labels,
            decoder_attention_mask=batch['target_mask']
        )

        loss = outputs[0]

        return loss

    def training_step(self, batch, batch_idx):
        loss = self._step(batch)

        tensorboard_logs = {"train_loss": loss}
        return {"loss": loss, "log": tensorboard_logs}
  
    def training_epoch_end(self, outputs):
        avg_train_loss = torch.stack([x["loss"] for x in outputs]).mean()
        tensorboard_logs = {"avg_train_loss": avg_train_loss}
        # return {"avg_train_loss": avg_train_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

    def validation_step(self, batch, batch_idx):
        loss = self._step(batch)
        return {"val_loss": loss}
  
    def validation_epoch_end(self, outputs):
        avg_loss = torch.stack([x["val_loss"] for x in outputs]).mean()
        tensorboard_logs = {"val_loss": avg_loss}
        return {"avg_val_loss": avg_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

    def configure_optimizers(self):
        "Prepare optimizer and schedule (linear warmup and decay)"

        model = self.model
        no_decay = ["bias", "LayerNorm.weight"]
        optimizer_grouped_parameters = [
            {
                "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
                "weight_decay": self.hparams.weight_decay,
            },
            {
                "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
                "weight_decay": 0.0,
            },
        ]
        optimizer = AdamW(optimizer_grouped_parameters, lr=self.hparams.learning_rate, eps=self.hparams.adam_epsilon)
        self.opt = optimizer
        return [optimizer]
  
    def optimizer_step(self, epoch, batch_idx, optimizer, optimizer_idx, second_order_closure, 
                       on_tpu=None, using_lbfgs=None):
        # if self.trainer.use_tpu:
        #     xm.optimizer_step(optimizer)
        # else:
        #     optimizer.step()
        optimizer.step(second_order_closure)
        # optimizer.zero_grad()
        self.lr_scheduler.step()
  
    def get_tqdm_dict(self):
        tqdm_dict = {"loss": "{:.3f}".format(self.trainer.avg_loss), "lr": self.lr_scheduler.get_last_lr()[-1]}

        return tqdm_dict

    def train_dataloader(self):
        train_dataset = get_dataset(tokenizer=self.tokenizer, type_path="train", args=self.hparams)
        dataloader = DataLoader(train_dataset, batch_size=self.hparams.train_batch_size, drop_last=True, shuffle=True, num_workers=4)
        t_total = (
            (len(dataloader.dataset) // (self.hparams.train_batch_size * max(1, self.hparams.n_gpu)))
            // self.hparams.gradient_accumulation_steps
            * float(self.hparams.num_train_epochs)
        )
        scheduler = get_linear_schedule_with_warmup(
            self.opt, num_warmup_steps=self.hparams.warmup_steps, num_training_steps=t_total
        )
        self.lr_scheduler = scheduler
        return dataloader

    def val_dataloader(self):
        val_dataset = get_dataset(tokenizer=self.tokenizer, type_path="val", args=self.hparams)
        return DataLoader(val_dataset, batch_size=self.hparams.eval_batch_size, num_workers=4)

# %%
logger = logging.getLogger(__name__)

class LoggingCallback(pl.Callback):
    def on_validation_end(self, trainer, pl_module):
        logger.info("***** Validation results *****")
        if pl_module.is_logger():
            metrics = trainer.callback_metrics
            # Log results
            for key in sorted(metrics):
                if key not in ["log", "progress_bar"]:
                    logger.info("{} = {}\n".format(key, str(metrics[key])))

    def on_test_end(self, trainer, pl_module):
        logger.info("***** Test results *****")

        if pl_module.is_logger():
            metrics = trainer.callback_metrics

        # Log and save results to file
        output_test_results_file = os.path.join(pl_module.hparams.output_dir, "test_results.txt")
        with open(output_test_results_file, "w") as writer:
            for key in sorted(metrics):
                if key not in ["log", "progress_bar"]:
                    logger.info("{} = {}\n".format(key, str(metrics[key])))
                    writer.write("{} = {}\n".format(key, str(metrics[key])))

# %% [markdown]
# Let's define the hyperparameters and other arguments. You can overide this `dict` for specific task as needed. While in most of cases you'll only need to change the `data_dir`and `output_dir`.
#
# Here the batch size is 8 and gradient_accumulation_steps are 16 so the effective batch size is 128

# %%
args_dict = dict(
    data_dir="", # path for data files
    output_dir="", # path to save the checkpoints
    model_name_or_path='t5-base',
    tokenizer_name_or_path='t5-base',
    max_seq_length=512,
    learning_rate=3e-4,
    weight_decay=0.0,
    adam_epsilon=1e-8,
    warmup_steps=0,
    train_batch_size=2,
    eval_batch_size=2,
    num_train_epochs=2,
    gradient_accumulation_steps=16,
    n_gpu=1,
    fp_16=False, # if you want to enable 16-bit training then install apex and set this to true
    opt_level='O1', # you can find out more on optimisation levels here https://nvidia.github.io/apex/amp.html#opt-levels-and-properties
    max_grad_norm=1.0, # if you enable 16-bit training then set this to a sensible value, 0.5 is a good default
    seed=42,
)

# %% [markdown]
# ## IMDB review classification

# %% [markdown]
# ### Download IMDB Data

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xvf aclImdb_v1.tar.gz

# %%
train_pos_files = glob.glob('aclImdb/train/pos/*.txt')
train_neg_files = glob.glob('aclImdb/train/neg/*.txt')

# %%
len(train_pos_files), len(train_neg_files)
# Out:
# (12500, 12500)

# %% [markdown]
# We will use 2000 samples from the train set for validation. Let's choose 1000 postive reviews and 1000 negative reviews for validation and save them in the val directory

# %%
# !mkdir aclImdb/val aclImdb/val/pos aclImdb/val/neg

# %%
random.shuffle(train_pos_files)
random.shuffle(train_neg_files)

val_pos_files = train_pos_files[:1000]
val_neg_files = train_neg_files[:1000]

# %%
import shutil

# %%
# for f in val_pos_files:
#     shutil.move(f,  'aclImdb/val/pos')
# for f in val_neg_files:
#     shutil.move(f,  'aclImdb/val/neg')

# %% [markdown]
# ### Prepare Dataset

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/transformers/models/t5/tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
ids_neg = tokenizer.encode('negative </s>')
ids_pos = tokenizer.encode('positive </s>')
len(ids_neg), len(ids_pos)
# Out:
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/transformers/models/t5/tokenization_t5.py:226: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# (2, 2)

# %% [markdown]
# All the examples are converted in the text-2-text format as shown in the paper. However I didn't use any task prefix here. The examples are encoded as follows,
# if the review is positive then the target is 'positive' else 'negative'
#
# **input**:  I went to see this
# movie with my husband, and we both
# thought the acting was terrible!"
#
# **target**: negative
#
# **input**:  Despite what others say,
# I thought this movie was funny.
#
# **target**: positive

# %% [markdown]
# The dataset below takes care of reading the review files and processing the examples in text-2-text format.
#
# It cleans the review text by removing the html tags. It also appends the eos token `</s>` at the end of input and target as required by the T5 model
#
# For T5 max input length is 512 and we can choose the max length for target sequence depending upon our dataset. The `T5Tokenizer` encodes both 'postive' and 'negative' as a single ids so I chose the max target length 2, extra 1 for the `</s>` token

# %%
class ImdbDataset(Dataset):
    def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
        self.pos_file_path = os.path.join(data_dir, type_path, 'pos')
        self.neg_file_path = os.path.join(data_dir, type_path, 'neg')

        self.pos_files = glob.glob("%s/*.txt" % self.pos_file_path)
        self.neg_files = glob.glob("%s/*.txt" % self.neg_file_path)

        self.max_len = max_len
        self.tokenizer = tokenizer
        self.inputs = []
        self.targets = []

        self._build()
  
    def __len__(self):
        return len(self.inputs)
  
    def __getitem__(self, index):
        source_ids = self.inputs[index]["input_ids"].squeeze()
        target_ids = self.targets[index]["input_ids"].squeeze()

        src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
        target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

        return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}
  
    def _build(self):
        self._buil_examples_from_files(self.pos_files, 'positive')
        self._buil_examples_from_files(self.neg_files, 'negative')
  
    def _buil_examples_from_files(self, files, sentiment):
        REPLACE_NO_SPACE = re.compile("[.;:!\'?,\"()\[\]]")
        REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

        for path in files:
            with open(path, 'r') as f:
                text = f.read()
      
            line = text.strip()
            line = REPLACE_NO_SPACE.sub("", line) 
            line = REPLACE_WITH_SPACE.sub("", line)
            line = line + ' </s>'

            target = sentiment + " </s>"

            # tokenize inputs
            tokenized_inputs = self.tokenizer.batch_encode_plus(
              [line], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
            )
            # tokenize targets
            tokenized_targets = self.tokenizer.batch_encode_plus(
              [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
            )

            self.inputs.append(tokenized_inputs)
            self.targets.append(tokenized_targets)

# %%
dataset = ImdbDataset(tokenizer, 'aclImdb', 'val',  max_len=512)
len(dataset)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:2339: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 2000

# %%
data = dataset[28]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# If the answer to this question is yes then you should enjoy this excellent movie Ive just seen it a couple of hours ago here in Paris where the action of the movie takes placeand I can still feel the huge trauma I received in the back of my eyesWhat a visual shock Ive never seen such a beautiful black&white photo and such a drastic change in the way of doing animated movies I strongly believe there will a before and after Renaissance similarly to what we saw with Pixar movies or the Akira and GhostInTheShell experiences This is a real breakthrough in the small world of animated movies and I hope this french initiative a small unknown french studio with a few young folks who had a dream named Renaissance will receive the success and recognition it deserves Vive la France</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# positive</s>

# %% [markdown]
# ### Train

# %%
# !mkdir -p t5_imdb_sentiment

# %%
args_dict.update({'data_dir': 'aclImdb', 'output_dir': 't5_imdb_sentiment', 'num_train_epochs':2})
args = argparse.Namespace(**args_dict)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    dirpath=args.output_dir, monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    precision= 16 if args.fp_16 else 32,
    gradient_clip_val=args.max_grad_norm,
    callbacks=[LoggingCallback()],
)

# %% [markdown]
# Define the `get_dataset` function to return the dataset. The model calls this function to get the train and val datasets. We are defining a dataset function so that we won't need to modify the model code at all. Redefine the function to return different dataset according to the problem. While this is not the best solution for now this works

# %%
def get_dataset(tokenizer, type_path, args):
    return ImdbDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %% [markdown]
# **Initialize model**

# %%
model = T5FineTuner(args)

# %% [markdown]
# **Initialize trainer**

# %%
trainer = pl.Trainer(**train_params)
# Out:
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:474: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %% [markdown]
# **start fine-tuning**

# %%
trainer.fit(model)
# Out:
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/pytorch_lightning/trainer/configuration_validator.py:92: UserWarning: When using `Trainer(accumulate_grad_batches != 1)` and overriding `LightningModule.optimizer_{step,zero_grad}`, the hooks will not be called on every batch (rather, they are called on every optimization step).
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA GeForce RTX 3070 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 222 M
# -----------------------------------------------------
# 222 M     Trainable params
# 0         Non-trainable params
# 222 M     Total params
# 891.614   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=2` reached.

# %%
# !mkdir t5_base_imdb_sentiment

# %%
## save the model this way so next time you can load it using T5ForConditionalGeneration.from_pretrained
model.model.save_pretrained('t5_base_imdb_sentiment')

# %%
# !cp -r t5_base_imdb_sentiment drive/My\ Drive/

# %% [markdown]
# ### Eval

# %% [markdown]
# For inference we will use the `generate` method with greedy decoding with max length 2.

# %%
# !pip install -r ../requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117, https://download.pytorch.org/whl/cu117
# Requirement already satisfied: einops in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: tqdm in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 2)) (4.64.1)
# Requirement already satisfied: pillow in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: numpy in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 4)) (1.24.2)
# Requirement already satisfied: matplotlib in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 5)) (3.6.3)
# Requirement already satisfied: torch==1.13.0+cu117 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 7)) (1.13.0+cu117)
# Requirement already satisfied: torchvision==0.14.0+cu117 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 9)) (0.14.0+cu117)
# Requirement already satisfied: autopep8 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: jupyter in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: tensorboard in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 13)) (2.11.2)
# Requirement already satisfied: opencv-python in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 14)) (4.7.0.68)
# Requirement already satisfied: tensorflow in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 15)) (2.11.0)
# Requirement already satisfied: torchmetrics[image] in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 16)) (0.11.1)
# Requirement already satisfied: torchsummary in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: pandas in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 18)) (1.5.3)
# Requirement already satisfied: transformers in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 19)) (4.26.0)
# Requirement already satisfied: pytorch-transformers in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 20)) (1.2.0)
# Requirement already satisfied: imutils in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 21)) (0.5.4)
# Requirement already satisfied: pylint in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 22)) (2.16.1)
# Requirement already satisfied: imagen-pytorch in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 24)) (1.22.1)
# Requirement already satisfied: lion-pytorch in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 25)) (0.0.6)
# Requirement already satisfied: nltk in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from -r ../requirements.txt (line 26)) (3.8.1)
# Collecting scikit-learn
#   Using cached scikit_learn-1.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
# Requirement already satisfied: typing-extensions in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torch==1.13.0+cu117->-r ../requirements.txt (line 7)) (4.4.0)
# Requirement already satisfied: requests in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (2.28.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from matplotlib->-r ../requirements.txt (line 5)) (1.0.7)
# Requirement already satisfied: pycodestyle>=2.10.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from autopep8->-r ../requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: tomli in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from autopep8->-r ../requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: ipykernel in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (6.21.1)
# Requirement already satisfied: nbconvert in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (7.2.9)
# Requirement already satisfied: jupyter-console in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (6.4.4)
# Requirement already satisfied: qtconsole in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (5.4.0)
# Requirement already satisfied: notebook in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (6.5.2)
# Requirement already satisfied: ipywidgets in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter->-r ../requirements.txt (line 12)) (8.0.4)
# Requirement already satisfied: wheel>=0.26 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (0.38.4)
# Requirement already satisfied: setuptools>=41.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (65.5.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (2.16.0)
# Requirement already satisfied: absl-py>=0.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (1.51.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (1.8.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorboard->-r ../requirements.txt (line 13)) (3.19.6)
# Requirement already satisfied: h5py>=2.9.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (3.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (15.0.6.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (23.1.21)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (3.3.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (0.30.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (2.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from tensorflow->-r ../requirements.txt (line 15)) (0.4.0)
# Requirement already satisfied: lpips in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torchmetrics[image]->-r ../requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: scipy in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torchmetrics[image]->-r ../requirements.txt (line 16)) (1.10.0)
# Requirement already satisfied: torch-fidelity in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from torchmetrics[image]->-r ../requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: pytz>=2020.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pandas->-r ../requirements.txt (line 18)) (2022.7.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (0.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (0.13.2)
# Requirement already satisfied: filelock in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from transformers->-r ../requirements.txt (line 19)) (3.9.0)
# Requirement already satisfied: boto3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch-transformers->-r ../requirements.txt (line 20)) (1.26.67)
# Requirement already satisfied: sentencepiece in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch-transformers->-r ../requirements.txt (line 20)) (0.1.97)
# Requirement already satisfied: sacremoses in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch-transformers->-r ../requirements.txt (line 20)) (0.0.53)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (0.11.6)
# Requirement already satisfied: isort<6,>=4.2.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (5.12.0)
# Requirement already satisfied: astroid<=2.16.0-dev0,>=2.14.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (2.14.1)
# Requirement already satisfied: platformdirs>=2.2.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (3.0.0)
# Requirement already satisfied: dill>=0.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (0.3.6)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pylint->-r ../requirements.txt (line 22)) (0.7.0)
# Requirement already satisfied: triton in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (1.1.1)
# Requirement already satisfied: einops-exts in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.0.4)
# Requirement already satisfied: click in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (8.1.3)
# Requirement already satisfied: pytorch-lightning in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (1.9.2)
# Requirement already satisfied: datasets in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (2.9.0)
# Requirement already satisfied: pytorch-warmup in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.1.1)
# Requirement already satisfied: kornia in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.6.9)
# Requirement already satisfied: fsspec in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (2023.1.0)
# Requirement already satisfied: ema-pytorch>=0.0.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.2.1)
# Requirement already satisfied: beartype in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.12.0)
# Requirement already satisfied: accelerate in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (0.16.0)
# Requirement already satisfied: pydantic in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from imagen-pytorch->-r ../requirements.txt (line 24)) (1.10.5)
# Requirement already satisfied: joblib in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nltk->-r ../requirements.txt (line 26)) (1.2.0)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from astroid<=2.16.0-dev0,>=2.14.1->pylint->-r ../requirements.txt (line 22)) (1.9.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r ../requirements.txt (line 13)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r ../requirements.txt (line 13)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r ../requirements.txt (line 13)) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r ../requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard->-r ../requirements.txt (line 13)) (6.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests->torchvision==0.14.0+cu117->-r ../requirements.txt (line 9)) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard->-r ../requirements.txt (line 13)) (2.1.2)
# Requirement already satisfied: psutil in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from accelerate->imagen-pytorch->-r ../requirements.txt (line 24)) (5.9.4)
# Requirement already satisfied: botocore<1.30.0,>=1.29.67 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r ../requirements.txt (line 20)) (1.29.67)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r ../requirements.txt (line 20)) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from boto3->pytorch-transformers->-r ../requirements.txt (line 20)) (0.6.0)
# Requirement already satisfied: xxhash in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (3.2.0)
# Requirement already satisfied: multiprocess in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (0.70.14)
# Requirement already satisfied: aiohttp in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (3.8.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (11.0.0)
# Requirement already satisfied: responses<0.19 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (0.18.0)
# Requirement already satisfied: tornado>=6.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (8.0.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (5.9.0)
# Requirement already satisfied: ipython>=7.23.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (8.9.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (5.2.0)
# Requirement already satisfied: comm>=0.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (1.6.6)
# Requirement already satisfied: pyzmq>=17 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (25.0.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 12)) (1.5.6)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 12)) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 12)) (3.0.5)
# Requirement already satisfied: pygments in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-console->jupyter->-r ../requirements.txt (line 12)) (2.14.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-console->jupyter->-r ../requirements.txt (line 12)) (3.0.36)
# Requirement already satisfied: jupyterlab-pygments in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: bleach in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (6.0.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (2.0.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.5.0)
# Requirement already satisfied: defusedxml in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.7.2)
# Requirement already satisfied: nbformat>=5.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (5.7.3)
# Requirement already satisfied: tinycss2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.2.1)
# Requirement already satisfied: jinja2>=3.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (3.1.2)
# Requirement already satisfied: beautifulsoup4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 12)) (4.11.2)
# Requirement already satisfied: argon2-cffi in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (21.3.0)
# Requirement already satisfied: prometheus-client in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: terminado>=0.8.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (0.17.1)
# Requirement already satisfied: ipython-genutils in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from notebook->jupyter->-r ../requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pytorch-lightning->imagen-pytorch->-r ../requirements.txt (line 24)) (0.6.0.post0)
# Requirement already satisfied: qtpy>=2.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from qtconsole->jupyter->-r ../requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from aiohttp->datasets->imagen-pytorch->-r ../requirements.txt (line 24)) (6.0.4)
# Requirement already satisfied: zipp>=0.5 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r ../requirements.txt (line 13)) (3.12.1)
# Requirement already satisfied: jedi>=0.16 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.18.2)
# Requirement already satisfied: pickleshare in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.7.5)
# Requirement already satisfied: decorator in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: stack-data in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.6.2)
# Requirement already satisfied: backcall in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (4.8.0)
# Requirement already satisfied: jupyter-server>=1.17.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: fastjsonschema in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (4.17.3)
# Requirement already satisfied: wcwidth in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->-r ../requirements.txt (line 12)) (0.2.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r ../requirements.txt (line 13)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r ../requirements.txt (line 13)) (3.2.2)
# Requirement already satisfied: ptyprocess in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->jupyter->-r ../requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->-r ../requirements.txt (line 12)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 12)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (5.10.2)
# Requirement already satisfied: jupyter-server-terminals in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.4.4)
# Requirement already satisfied: websocket-client in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: jupyter-events>=0.4.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.6.3)
# Requirement already satisfied: anyio>=3.1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r ../requirements.txt (line 12)) (1.15.1)
# Requirement already satisfied: pure-eval in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: pycparser in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r ../requirements.txt (line 12)) (2.21)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: rfc3339-validator in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.17.0->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 12)) (0.1.4)
# Requirement already satisfied: uri-template in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.12)
# Requirement already satisfied: fqdn in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (2.3)
# Requirement already satisfied: isoduration in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (20.11.0)
# Requirement already satisfied: arrow>=0.15.0 in /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 12)) (1.2.3)
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-1.2.1 threadpoolctl-3.1.0
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %% [markdown]
# Let's visualize few predictions on test dataset

# %%
dataset = ImdbDataset(tokenizer, 'aclImdb', 'test',  max_len=512)
loader = DataLoader(dataset, batch_size=32, shuffle=True)
# Out:
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:2339: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/transformers/models/t5/tokenization_t5.py:226: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(

# %%
it = iter(loader)

# %%
batch = next(it)
batch["source_ids"].shape
# Out:
# torch.Size([32, 512])

# %%
# outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
#                               attention_mask=batch['source_mask'].cuda(), 
#                               max_length=2)
outs = model.model.generate(input_ids=batch['source_ids'], 
                              attention_mask=batch['source_mask'], 
                              max_length=2)

dec = [tokenizer.decode(ids) for ids in outs]

texts = [tokenizer.decode(ids) for ids in batch['source_ids']]
targets = [tokenizer.decode(ids) for ids in batch['target_ids']]

# %%
for i in range(32):
    lines = textwrap.wrap("Review:\n%s\n" % texts[i], width=100)
    print("\n".join(lines))
    print("\nActual sentiment: %s" % targets[i])
    print("Predicted sentiment: %s" % dec[i])
    print("=====================================================================\n")
# Out:
# Review: I have never read a Jacqueline Susann novel but I have also seen Valley of the Dolls based
# on another of her books On both occasions I thought the movie is probably better than the book and
# will further improve with age certainly contrary to the books The reason being that a movie focuses
# more on a specific style in fashion design and behavior patterns And in this aspect The Love Machine
# offers quite a lot The set design fits the story perfectly And all the characters fit in too Theyre
# perfect in the way that they complete a well balanced general picture They are superficial and do
# not develop it is true but in this movie I wouldnt want it any differentDavid Hemmings reprises the
# role he played in Antonionis Blow Up And its more than a ripoff Hes a fashion photographer looks
# visibly aged and seems to start going slightly to seed Robert Ryan reprises the role he played in
# Max Ophüls Caught he is Smith Ohlrig all over again greedy bored and boring uninspired and
# uninspiring Its possible Ryan did not want to be in this picture and acted accordingly on the other
# hand he might have thought a lot about his part and then given a carefully studied performance
# Whatever happened it fits the picture Dyan Cannon is great fantastic wardrobe she dominates every
# scene shes in and is involved in the two highlights of the movie the burning of a luxurious bed and
# the knocking down of the Hemmings character with a Academy Award statuetteThe title The Love Machine
# is of course meant ironically Robin Stone is a kind of a Barry Lyndon of the pop era incidentally
# the movie IS slightly kubrickysh That he chooses a TV station to work his way up to the top seems to
# be a mere coincidence He sees love meaning sexual favors merely as a means for personal advancement
# There are rather scary hints of a troubled sexuality which are not explored in the movie
# Homosexuality is treated very casually probably not the standard for mayor movies of the period The
# open cynicism of the TV executives need not fear comparison with other good movies about the subject
# like A Face in the Crowd or Network or Truman Show They are producing crap they agree among
# themselves its crap and they know they will make a lot of dough with itI did not regret spending</s>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: Terence Stamp can carry off anything but this is still a shallow onedimensional movie Its
# nice to look at so are the actors and if youre into drag queens I guess you might like it a lot but
# the plot and characters are as thin as cardboard Its one of those politically correct movies that
# warps everything else in order to make a minority lifestyle seem warm and cuddly It gets a lot of
# mileage out of bitchy dialogue which is amusing in this sanitized form I guess Ninety percent of the
# action is parading around in gaudy costumes in incongruous situations The dramatic content is a
# token appendage they hardly try to get you to take it seriously</s><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: <unk> Rock star is not on its way to any <unk> stairway to heaven category as one of the
# best rock films of all time but it does make you <unk> jump from time to time because of its
# highlevel energy The films theme is on a diehard rock group fanatic who actually becomes the lead
# singer of his favorite band The story is based upon the true story on what happened to the heavy
# metal band Judas Priest If you think this movie is filled with a witty screenplay and intellect
# direction then you got <unk> another thing coming However what did <unk> shook me all night long was
# the fine acting of Jennifer Aniston as the rock stars devoted girlfriend I could not say the same
# about the rock star himself Mark Wahlberg was much better as a porn star than a rock star I did
# enjoy the 80s retrospect journey the movie intakes It reminded me of my teenage years where
# everything <unk> smelled like teen spirit I guess the film is worth a viewing but for you to have a
# better time watching it make sure you bring along some <unk> girls girls girls *** Average</s><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: Admirable but weak James Bond film mainly because both the hero Bond and villain Blofeld
# were seriously miscast Lazenby is too big and innocent looking to play Bond He looks and acts more
# like the goodnatured but dimwitted sidekick in a police action movie The director and writer try to
# establish his credibility but his saying of lines like Royal Baluga North of the just arent
# effective in establishing him as this worldly and suave rogue Savalas doesnt do a bad job but his
# characterization and behavior is more fitting of a mob gangster The best portrayed characters of the
# movie are those of Tracy and her father But the performances by those actors when sharing the screen
# with Lazenby only serve to emphasize his deficiencies as an actor This movie is too long 140 mins
# for a Bond film and doesnt offer any excitement until Bonds mountain escape where it begins to pick
# up This film tries very hard but falls short Many Bondian elements are present and the climatic
# battle is top notch but I always get a sense of something missing when watching this one</s><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: Oh but this is woeful One good actor after another turns in lamentable dialogue in half
# hearted fashion under what must have been incredibly pedestrian direction to consider it acceptable
# I like Robert Carlyle and Joanne Whalley is one of my favourite actresses Tom Courtney can act well
# when pushed and David Suchet is a professional of the highest integrity but they all wallowed around
# like fish in a barrel of watery gin I swear Courtney was inebriated on painkillers or both Was there
# a good performance in the whole thing Well yes David Hood as the junior underground engineer whose
# mate got washed away looked like he was taking the thing seriously and credit to him for that it
# cant be easy when all around are losing theirs so to speak or maybe his scenes came under the
# direction of the assistant director if there was one I just dont know what these people were doing
# in a film that was this poor other than paying the bills obviously I cant begin to say how
# disappointed I am in them YOU SHOULD BE ASHAMED OF YOURSELVES Any positives other than David Hood
# the third yes The aerial shots of London largely submerged were very well done and the effects
# artists responsible deserved better than to have their fine work punctuated by such a shallow
# storyif youll forgive the expression as those few people that do see them will do so on a far
# smaller screen than would be to best advantage Whats going on here why are British film makers
# trying to imitate such characterless spectacle driven tabloid level genres as the disaster movie and
# then doing it even worse than the Americans Gritty realism character integrity the capture of real
# emotion in a way that makes you feel it and care The Family Way Spring and Port Wine Get Carter The
# long Good Friday TrainspottingDont get me wrong I like a bit of escapist hokum The real Italian Job
# The Adventures of Tom Jones but oh that it should come to this there was more realistic drama in
# Carry On Camping</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: Aaran is one of the movies where you find the loop holes in Indian Cinema Here is one good
# example to show how excellent writers directors and actors succumb to the producers Here is one of
# the most wonderful actors Mohanlal acting in a movie about a real story in Kashmir The seriousness
# of the film is slaughtered with sub standard comic scenes and songs There is this character Havaldar
# Jaykumar who in reality is the son of the producer of the film Hence he doesnt have a hair cut
# despite his officer asking him to do so This kid doesnt know what is acting and he is the hero of
# the movie God Help Indian Cinema with such producersThis movie is a pathetic display of what happens
# in Kashmir A sensible viewer can intuitively understand the constraints of such wonderful writers
# actors and directors who want to share their real life experiences But the unfortunate part is that
# a movie about the highest ranks in Indian Militia turns out to be a pathetic display that only makes
# one think that the movie was stupidWe should oust such producers in the film industry and pave way
# for good cinema</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: A bunch of sorority girls make a new pledge spend the night in a creepy mausoleum Of course
# the recently deceased dont stay deceased for long and all hell breaks looseOne Dark Night is an
# enjoyable 80s horror with some ghastly dead bodies floating around that are being controlled by the
# spirit of a dead psychic RaymarThere is no gore and nuditybut the atmosphere of a mausoleum is very
# eerieThe acting is solidbut the script takes too much time to develop the characters until the final
# 20 minutes that Raymar finally breaks out of his graveThe cinematography is impressive and the the
# mausoleum is a great location for the climactic eventsThe film takes so long to get going and this
# is its major flaw7 out of 10</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: If you are going to make a movie from any book be sure that the characters are consistant
# with that book This movie not only defied the Biblical story that has been told for thousands upon
# thousands of years to children one way or another but it clearly took liberties that no adaptation
# would probably ever try At least the Lord of the Rings is close enough to the books that people
# understand the story more if they read the books than this Noahs Ark tried to</s><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: Coltrane and Idle are members of a bank robbery gang who double cross their leader during a
# robbery They hide out in a nunnery school and disguise themselves appropriately to avoid detection
# from the mob and the police Alot of catholic humor and slapstick but the script is kinda thin as are
# the laughs There is a GOOD shower scene though on a scale of one to ten4</s><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: The SevenUps seems like a replay of The French Connection which was released two years prior
# Both the late Roy Scheider and Tony Lo Bianco make appearances as well as stunt driver Bill
# HickmanBut we arent dealing with French drug baddies instead we are dealing with a war against
# assorted hoods and criminals after a cop is brutally killed by a hoodlum We get to see
# unpleasantness and a pre1990s New York CityI love watching this film because it is exciting to see
# the action and it is a reminder of a cooler time That said when one compares the car chases Mr
# Hickman had involvement in the three most compared This movie Bullitt and The French Connection Each
# chase scene has its own qualities and this one is simply superbAnd I am glad this title has seen the
# light of day on DVD</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: Directed by Jim Wynorski Chopping Mall Return of the Swamp Thing Cheerleader Massacre is the
# fourth installment in the Slumber Party Massacre series Just think about it its the fourth chapter
# of a slasher series that no one really cares about So how could this even be good Well its not But
# since when did slasher films have to be good Cheerleader Massacre is entertaining thats for sure But
# in the entertainment field weve seen better thats for sure too As you can see Im not sure about
# where I stand concerning this movie Those who watch slashers only for nudity will be more than
# satisfied This movies all boobs but unfortunately no blood or not enough I think Im being generous
# with this movie because I had a good time watching it and I really enjoy watching slasher movies
# even as bad as they sometimes are If you want me to be sincere The Slumber Party Massacre Part 1 is
# the best one and all the others are a waste of time so I guess I have a lot of time to waste For
# more fun watch Sleepaway Camp 2 and Cheerleader Camp</s><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: The French people are not known to be great movie producersThough their Amelie scores high
# points at the Oscars Asterix et Obelix is a very different film of what I am used to from the French
# It is a great movie especially for kids The only thing that boddert me was that it was spoken in
# French and subtiteld Normally with the english spoken movies here in the Netherlands I dont have to
# read the subtitles But with the French language you just have to read to understand The story it
# self is just great with Obelix who doesnt recall him self of be<unk> ng fat but there also nice
# details mainly in names like brucewillix and malcomix You all know the story from the comic books
# and this movie shows all most slide by slide the book Every thing is in it from the Sfinx nose
# braking till pirate red beards lose of three more ships I would say a great movie for the weekend
# with the children</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: CACTUS FLOWER was a delightful 1969 comedy based on a Neil Simon play about a dentist Walter
# Matthau having an affair with a young free spirited woman Goldie Hawn totally unaware that his
# devoted nurseassistantIngrid Bergmanis in love with him Matthau can play this kind of role in his
# sleep and he doesnt disappoint as the philandering dentist Dr Julian Winston who is dating one woman
# but really has no clue that hes in love with another Goldie Hawn won an Oscar for her sparkling
# performance as Toni Simmons the aging flower child who slowly comes to realize she is trapped in a
# dead end affair and is not as dim as she appears on the surface But the real pleasure for me in this
# film was the performance of the legendary Ingrid Bergman as Stephanie Dickinson Dr Winstons
# completely devoted assistant who is willing to to bury and sacrifice her own happiness as long as Dr
# Winston is happy with Tony Bergman is luminous in this film looking absolutely beautiful though the
# camera has always loved her and showing an unforeseen knack for light comedy Yes the dialogue and
# the settings are slightly dated but the story is timeless and the performances by the stars make it
# imminently watchable</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: the only reason i bought this DVD is because cynthia rothrock is in itnow everybody knows
# she is the queen of martial arts b moviesthe trouble is this is not a martial arts moviecynthia
# rothrock has about a minute or so of fight scenes in this stupid movienow if you were a film maker
# and you had cynthia rothrock in your movie wouldnt you want to have a lot of martial arts action all
# she does in this movie is walk around looking bored just like i was when i watched this pile of
# crapi own a lot of her movies and they are all b movies but at least they had some cool fight scenes
# in themif you are a martial arts fan avoid this no matter whatim still mad i wasted 4 dollars to buy
# this DVD</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: Wow What a movie if you want to blow your budget on the title and have it look real bad ask
# the guys that made this movie on how to do that They could have spent the money on a good rewrite or
# something else Or they could have spent it on beer when they made this movie at least it would have
# come out better</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: Opera the US title is terror at the opera is somewhat of a letdown after some of Darios
# other movies like Phenomena Tenebre and Suspiria i still cant find Inferno anywhere its one of those
# movies that has a great first half but midway through its like someone started slowly letting the
# air out of the screenplay and logicthe basic plot involves a beautiful opera singer who is being
# stalked by a deranged obsessed fan this killer begins killing people close to her in a most unique
# fashion he binds and gags her and tape tiny sharp pins under her eyelids so if she tries to close
# her eyes shell gouge out her eyes this forces her to watch while the killer murders her
# acquaintances in typically brutal and gory Argento fashionunfortunately about midway through the
# film becomes sluggish and illogical this is especially directed towards the killers motivations i
# still havent completely figured out why hes such a nut the ending especially come out of left field
# in the worst possible sensebut for about the first hour or so this is some of Darios best filmmaking
# and the camera work is breathtaking too bad it couldnt maintain it through to the endrating7</s><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: I wrote this as a two part review Part two has spoilersPart 1 No this isnt that one about
# the sex with car accidents This is the one about racism in LA You know the one where everybody is a
# racist and race is the topic on everybodys mind at all times RaceIts like the movie has a form of
# turrets syndrome where race is the constant theme Race Racist Racism Race Relations Relay racePaul
# Haggis made a movie which took the structure of Magnolia which was used to show the disconnect of
# people who are tangentially connected and then screwed it into a 153 mental vomit about racism in
# America RACE In the 24 hour period we have 7 stories running parallel all connected and about race
# The first hour people say ridiculous stuff and do absurd things in an effort to be real about racism
# in AmericaFor example the story with Ludicrous and Larenz Tate provides the comic relief Too bad the
# first half of their story is lifted straight from The Bonnie Situation in Pulp Fiction RACISM Their
# section is the Quentin Tarantino section where instead of being cool and talking about foot massages
# and religion the characters talk about race and racism CONSTANTLY The other good thing about it is
# the Mexican story when the Mexican guy is talking to his daughter He gives her his invisible
# impenetrable cloak to protect her from bullets Decent writing but thats only because the writers
# have had daughters and know what they would say in his placeThe rest of the stories are extremely
# ludicrous The Hindi does not act in any semblance of realism The scene where hes trying to get the
# lock fixed and the Mexican tells him he needs a new door is abbreviated and stupid Why would anybody
# act like that Is it realistic NOOO It reminds me more of the convenience store clerk from The Doom
# Generation Six Dollar Sixty Six Cents girly If i ever watch the second half of the movie I hope his
# head is shot off and his bodiless head starts coughing up relishI havent mentioned race in over a
# paragraph RACE RACISM RACE FOR THE SUN Better Then there is the black guy who wants to be white Matt
# Dillon who has a chip on his shoulder against blacks Ryan Phillippe who looks beautiful and does
# nothing and various other bad actors acting badly with bad dialog</s>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: This is just one of the hundred million movies where the directors try to shove too much
# drama into a movie thats not dramatic at all Like in the beginning the part where the monk dude
# shoved the arrow into his own hand then shot that same arrow into the gargoyle five minutes laterno
# sense whatsoeverThe only thing worse than the plot line is the CGI which would be greatly rivaled by
# a homemade flash movie The actors look like theyre doing their hardest to portray a bunch of 70s
# robots the dialogue makes so little sense its not funnyMany things just HAPPEN with no explanation
# as to how or why such as a lady suddenly wandering around a zoo that had shut down hours ago And
# when she sees this THING flying towards her her first reaction is to take a picture rather than what
# she does a full ten minutes laterpowerwalking not even running like her life depended on itwhich
# obviously it doesntOverall not recommended Makes me wish they still did new episodes of MST3K</s><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: I bought this DVD as part of a set of 50 historic classics Its hardly a classic and as the
# plot was updated to the time of its release is not historic either The actual title on the DVD is
# Indecent and additionally subtitled The Private Life of Becky Sharp Myrna Loy is not very convincing
# although in her defense she is saddled with an awful script and trite dialogue As with many early
# talkies and especially ones made by smaller studios there is little skill demonstrated by the cast
# and crew Loy does wear a few gowns that are quite stylish but her costumes and makeup in the later
# scenes are overdone The one saving grace is a tolerable performance by Billy Bevan who plays one of
# her many suitors</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# ...
# of the period in reality she tended to support Maos Communist regime but here she is shown as firmly
# antiCommunist This is not however primarily an issue movie about either racialism or politics but
# rather a romance a good example of what would have been known at the time as a womans picture Such
# films although mostly made by male directors were mostly aimed at female audiences They dealt with
# love and romance often unhappy romance from the womans point of view and had a strong female
# character in the leading role The genre often provided roles for actresses older than the heroines
# of standard romances Earlier examples were normally in monochrome but by the fifties they generally
# as here used lush sumptuous colourAlthough a Chinese or Eurasian actress would have been more
# convincing in the role</s>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: Some Spoilers PRC quickie that has J Carrol Naish playing Dr Igor Markoff whos not really Dr
# Karkoff but an impostor who took over his identity back in Europe The real Dr Karkoff had a affair
# with DrMarkoffs wife that lead to him to murder the real DrMarkoff and then having his wife Lenore
# infected with acromegaly that made her look like the Elephant Mans sister This was done so that no
# one would ever want to look at her and he could keep Lenore all to himself but the disturbed Lenore
# later got even with her insane husband by killing herself This nut the fake Dr Markoff then spots
# Patricia Lawrence Wanda McKay one evening at the theater where her father Tony Lawernce Ralph Morgan
# a world famous pianist is giving a concert Enchanted by the lovely Patricia whos a dead ringer for
# his dead wife Lenore Dr Markoff becomes obsessed with her and goes to extreme lengths to marry her
# even though shes wants nothing to do with himAfter getting ridicules in his efforts to get Patricia
# to fall in love with him by sending her flowers with syrupy love notes attached to then as much as
# five times a dayTony goes to see the crazed Dr Mankoff to tell him to stop annoying his daughter Its
# then that Tony ends up getting knocked out by the good doctor who has him injected with a dose of
# acromegaly that turns him into a somewhat unsightly fellow With his hands and body swelling up and
# not being able to play his beloved piano Tony is told by his Doctor Dr AdamsSam Flint that the only
# one who can cure him of that dreadful disease is non other then Dr Markoff the person who gave it to
# him The movie has the usual subplots with Dr Markoffs assistant MaxineTala Birell whos also in love
# with him jealous of the phony doctor making a play for Patricia Theres also Dr Markoffs hulking
# butler Glenn Strange who like his pet gorilla is just a big clumsy oaf who cant even subdue Maxine
# whos less the half the size Strange ends up getting bopped on the head and knocked out cold by
# Patricias boyfriend Bobby Blake</s>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: Ive seen this movie twice on Transilvania International Film FestivalTIFF the movie is in
# competition and I really hope that Esteban Sapir will get one of the awards at least the best image
# award As a silent cinema fan Im interested in contemporary movies that quote or recreate the
# language of the yesteryear cinema The previous reviewer emphasized the quotes from Fritz Lang and Fr
# W Murnau As I see it the movie references directly Langs Metropolis and the allegoricalparabolic
# character of his plots But I didnt see Murnau in it Theres a more obvious Melieshomage though the
# Moon with a here cigarsmoking human face and the papermade painted mountains and citylandscapes I
# enjoyed the film mostly for its visuals and in the meantime I found very interesting the story on
# muteness and the creative means of communication used by the inhabitants of the voiceless city From
# this perspective this movie is an unique reflexion on the muteness of the silent cinema because in
# the films of the silent period one can hardly find stories with mute characters In this case can be
# questioned whether the story on the stolen voices was the motivation for the silent film form or
# theres an intention to play upon the muteness of the silent films Another example of this kind of
# reflexion I found in Guy Maddins Carefulwhere the inhabitants of a mountainvillage have restrictions
# in using their voices I intend to write a paper on it if you know movies related to this topic
# please let me know I highly recommend Esteban Sapirs film to every moviegoer one of the critics
# called it the jewel of the festivalPS Winners were announced and the film won the award for best cin
# ematography</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: Not your everyday Tom and Jerry short for many reasons One theres a voiceover narration by
# Jerry which is odd because Tom and Jerry rarely speak Two the two are friends which was also rare
# and seldom works as well as the more adversarial shorts do Third and most importantly the cartoon is
# rarely humorous by design and the jokes here are dry chuckles with a little cough and a bubble of
# blood at the end Think a Tom and Jerry cartoon directed by Tim Burton Not wholly successful but it
# largely does work The creepiest ending for an MGM short that I can recall Not for everyone and proof
# that these shorts were never intended solely with children as the target audience Well worth
# watching Recommended with the caveats above</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: OK here is the deal I love action movies and generally have no problem suspending a great
# deal of disbelief over plot holes or other implausible actions However this movie went far beyond
# minor flaws and went straight to the ridiculous Let me get this straight The police send a notorious
# gangster and cop killer along with a number of other prisoners on a bus with a grand total of two
# guards They then are forced to stop at a precinct where precisely two cops are working one of which
# is a day away from retirement and the other is a burn out Apparently the building was about to be
# shut down so somehow the police decided that everyone else in the entire precinct got the night off
# for new years eve Right But wait it gets better Gabriel Byrne shows up to take out Fishburne before
# he can rat him and other dirty cops out although we never find out anything about their relationship
# or dealings Interestingly the cops launching the assault on the precinct are in full SWAT gear with
# night vision goggles assault rifles the whole nine yards Later on they even bring in a helicopter
# with MORE people in full gear Im not a cop but Im pretty sure you cant just waltz out of the station
# with an entire swat platoon worth of equipment without someone asking what you are doing And the
# police helicopter In the supposedly terrible winter storm Also no one near the precinct happens to
# hear or see this major siege going on with flash grenades and heavy rifle fire going off I mean
# seriously come on I know this is set in Detroit but even there it would raise suspicion on a
# supposedly top secret mission I also love the fact that they find a Tommy Gun in the evidence room
# and somehow the gun still works and has bullets that are still intact and usableI could live with
# some of these problems if there werent other glaring issues also For one the opening couple minutes
# of the movie are shot nicely in a very frenetic and hyperactive way and I thought was going to set
# the tone for the rest of the movie Unfortunately I was wrong The remainder of the film has no sense
# of pacing or tension or drama The characters dont relate to each other in any way which is probably
# largely due to the fact that they arent particularly interesting There isnt enough</s>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: What can i say about Tromeo and Juliet other than if you like twisted Troma machinations
# then you MUST see this movie This is my absolute favorite Troma flick and i have seen almost all of
# them Penis monsters cecsarian births to live rats and popcorn lesbianism steamy sex scenes in
# plexiglass boxes incest nipple piercing dismemberment shameless Troma plugs and computer
# masturbationHow can one go wrong It amazingly follows the original story very closely YOU MUST SEE
# THIS MOVIE OH and speaking of shameless plugsCheck out Jane Jensens Comic Book Whore CD on
# Interscope records It is awesome</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: I cant add much to what has been said already except Im going to have to because of the 10
# lines minimum policyIve actually got this on a VHStoDVD copy but the quality is quite poor and I
# desperately need for it to be officially releasedI can just imagine what extras I would like to see
# Tim Healys character swearing his way through one of those Football Bloopers type programmes would
# be great You can imagine it now cant you But of course it looks like most people will have to carry
# on dreaming about a DVD releaseSurely to God there must be someone in the DVD releases department at
# ITV who also knows something about British culture is web savvy and has enough about them to look at
# IMDb now and again Oh well</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>negative
# =====================================================================

# %% [markdown]
# Now predict on all the test dataset

# %%
loader = DataLoader(dataset, batch_size=32, num_workers=4)
model.model.eval()
outputs = []
targets = []
for batch in tqdm(loader):
    outs = model.model.generate(input_ids=batch['source_ids'], 
                              attention_mask=batch['source_mask'], 
                              max_length=2)

    dec = [tokenizer.decode(ids) for ids in outs]
    target = [tokenizer.decode(ids) for ids in batch["target_ids"]]

    outputs.extend(dec)
    targets.extend(target)
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]

# %% [markdown]
# Let's check if the model generates any invalid text

# %%
for i, out in enumerate(outputs):
    if out not in ['positive', 'negative']:
        print(i, 'detected invalid prediction')
# Out:
# 0 detected invalid prediction
# 1 detected invalid prediction
# 2 detected invalid prediction
# 3 detected invalid prediction
# 4 detected invalid prediction
# 5 detected invalid prediction
# 6 detected invalid prediction
# 7 detected invalid prediction
# 8 detected invalid prediction
# 9 detected invalid prediction
# 10 detected invalid prediction
# 11 detected invalid prediction
# 12 detected invalid prediction
# 13 detected invalid prediction
# 14 detected invalid prediction
# 15 detected invalid prediction
# 16 detected invalid prediction
# 17 detected invalid prediction
# 18 detected invalid prediction
# 19 detected invalid prediction
# 20 detected invalid prediction
# 21 detected invalid prediction
# 22 detected invalid prediction
# 23 detected invalid prediction
# 24 detected invalid prediction
# 25 detected invalid prediction
# 26 detected invalid prediction
# 27 detected invalid prediction
# 28 detected invalid prediction
# 29 detected invalid prediction
# 30 detected invalid prediction
# 31 detected invalid prediction
# 32 detected invalid prediction
# 33 detected invalid prediction
# 34 detected invalid prediction
# 35 detected invalid prediction
# 36 detected invalid prediction
# 37 detected invalid prediction
# 38 detected invalid prediction
# 39 detected invalid prediction
# 40 detected invalid prediction
# 41 detected invalid prediction
# 42 detected invalid prediction
# 43 detected invalid prediction
# 44 detected invalid prediction
# 45 detected invalid prediction
# 46 detected invalid prediction
# 47 detected invalid prediction
# 48 detected invalid prediction
# 49 detected invalid prediction
# 50 detected invalid prediction
# 51 detected invalid prediction
# 52 detected invalid prediction
# 53 detected invalid prediction
# 54 detected invalid prediction
# 55 detected invalid prediction
# 56 detected invalid prediction
# 57 detected invalid prediction
# 58 detected invalid prediction
# 59 detected invalid prediction
# 60 detected invalid prediction
# 61 detected invalid prediction
# 62 detected invalid prediction
# 63 detected invalid prediction
# 64 detected invalid prediction
# 65 detected invalid prediction
# 66 detected invalid prediction
# 67 detected invalid prediction
# 68 detected invalid prediction
# 69 detected invalid prediction
# 70 detected invalid prediction
# 71 detected invalid prediction
# 72 detected invalid prediction
# 73 detected invalid prediction
# 74 detected invalid prediction
# 75 detected invalid prediction
# 76 detected invalid prediction
# 77 detected invalid prediction
# 78 detected invalid prediction
# 79 detected invalid prediction
# 80 detected invalid prediction
# 81 detected invalid prediction
# 82 detected invalid prediction
# 83 detected invalid prediction
# 84 detected invalid prediction
# 85 detected invalid prediction
# 86 detected invalid prediction
# 87 detected invalid prediction
# 88 detected invalid prediction
# 89 detected invalid prediction
# 90 detected invalid prediction
# 91 detected invalid prediction
# 92 detected invalid prediction
# 93 detected invalid prediction
# 94 detected invalid prediction
# 95 detected invalid prediction
# 96 detected invalid prediction
# 97 detected invalid prediction
# 98 detected invalid prediction
# 99 detected invalid prediction
# 100 detected invalid prediction
# 101 detected invalid prediction
# 102 detected invalid prediction
# 103 detected invalid prediction
# 104 detected invalid prediction
# 105 detected invalid prediction
# 106 detected invalid prediction
# 107 detected invalid prediction
# 108 detected invalid prediction
# 109 detected invalid prediction
# 110 detected invalid prediction
# 111 detected invalid prediction
# 112 detected invalid prediction
# 113 detected invalid prediction
# 114 detected invalid prediction
# 115 detected invalid prediction
# 116 detected invalid prediction
# 117 detected invalid prediction
# 118 detected invalid prediction
# 119 detected invalid prediction
# 120 detected invalid prediction
# 121 detected invalid prediction
# 122 detected invalid prediction
# 123 detected invalid prediction
# 124 detected invalid prediction
# 125 detected invalid prediction
# 126 detected invalid prediction
# 127 detected invalid prediction
# 128 detected invalid prediction
# 129 detected invalid prediction
# 130 detected invalid prediction
# 131 detected invalid prediction
# 132 detected invalid prediction
# 133 detected invalid prediction
# 134 detected invalid prediction
# 135 detected invalid prediction
# 136 detected invalid prediction
# 137 detected invalid prediction
# 138 detected invalid prediction
# 139 detected invalid prediction
# 140 detected invalid prediction
# 141 detected invalid prediction
# 142 detected invalid prediction
# 143 detected invalid prediction
# 144 detected invalid prediction
# 145 detected invalid prediction
# 146 detected invalid prediction
# 147 detected invalid prediction
# 148 detected invalid prediction
# 149 detected invalid prediction
# 150 detected invalid prediction
# 151 detected invalid prediction
# 152 detected invalid prediction
# 153 detected invalid prediction
# 154 detected invalid prediction
# 155 detected invalid prediction
# 156 detected invalid prediction
# 157 detected invalid prediction
# 158 detected invalid prediction
# 159 detected invalid prediction
# 160 detected invalid prediction
# 161 detected invalid prediction
# 162 detected invalid prediction
# 163 detected invalid prediction
# 164 detected invalid prediction
# 165 detected invalid prediction
# 166 detected invalid prediction
# 167 detected invalid prediction
# 168 detected invalid prediction
# 169 detected invalid prediction
# 170 detected invalid prediction
# 171 detected invalid prediction
# 172 detected invalid prediction
# 173 detected invalid prediction
# 174 detected invalid prediction
# 175 detected invalid prediction
# 176 detected invalid prediction
# 177 detected invalid prediction
# 178 detected invalid prediction
# 179 detected invalid prediction
# 180 detected invalid prediction
# 181 detected invalid prediction
# 182 detected invalid prediction
# 183 detected invalid prediction
# 184 detected invalid prediction
# 185 detected invalid prediction
# 186 detected invalid prediction
# 187 detected invalid prediction
# 188 detected invalid prediction
# 189 detected invalid prediction
# 190 detected invalid prediction
# 191 detected invalid prediction
# 192 detected invalid prediction
# 193 detected invalid prediction
# 194 detected invalid prediction
# 195 detected invalid prediction
# 196 detected invalid prediction
# 197 detected invalid prediction
# 198 detected invalid prediction
# 199 detected invalid prediction
# 200 detected invalid prediction
# 201 detected invalid prediction
# 202 detected invalid prediction
# 203 detected invalid prediction
# 204 detected invalid prediction
# 205 detected invalid prediction
# 206 detected invalid prediction
# 207 detected invalid prediction
# 208 detected invalid prediction
# 209 detected invalid prediction
# 210 detected invalid prediction
# 211 detected invalid prediction
# 212 detected invalid prediction
# 213 detected invalid prediction
# 214 detected invalid prediction
# 215 detected invalid prediction
# 216 detected invalid prediction
# 217 detected invalid prediction
# 218 detected invalid prediction
# 219 detected invalid prediction
# 220 detected invalid prediction
# 221 detected invalid prediction
# 222 detected invalid prediction
# 223 detected invalid prediction
# 224 detected invalid prediction
# 225 detected invalid prediction
# 226 detected invalid prediction
# 227 detected invalid prediction
# 228 detected invalid prediction
# 229 detected invalid prediction
# 230 detected invalid prediction
# 231 detected invalid prediction
# 232 detected invalid prediction
# 233 detected invalid prediction
# 234 detected invalid prediction
# 235 detected invalid prediction
# 236 detected invalid prediction
# 237 detected invalid prediction
# 238 detected invalid prediction
# 239 detected invalid prediction
# 240 detected invalid prediction
# 241 detected invalid prediction
# 242 detected invalid prediction
# 243 detected invalid prediction
# 244 detected invalid prediction
# 245 detected invalid prediction
# 246 detected invalid prediction
# 247 detected invalid prediction
# 248 detected invalid prediction
# 249 detected invalid prediction
# 250 detected invalid prediction
# 251 detected invalid prediction
# 252 detected invalid prediction
# 253 detected invalid prediction
# 254 detected invalid prediction
# 255 detected invalid prediction
# 256 detected invalid prediction
# 257 detected invalid prediction
# 258 detected invalid prediction
# 259 detected invalid prediction
# 260 detected invalid prediction
# 261 detected invalid prediction
# 262 detected invalid prediction
# 263 detected invalid prediction
# 264 detected invalid prediction
# 265 detected invalid prediction
# 266 detected invalid prediction
# 267 detected invalid prediction
# 268 detected invalid prediction
# 269 detected invalid prediction
# 270 detected invalid prediction
# 271 detected invalid prediction
# 272 detected invalid prediction
# 273 detected invalid prediction
# 274 detected invalid prediction
# 275 detected invalid prediction
# 276 detected invalid prediction
# 277 detected invalid prediction
# 278 detected invalid prediction
# 279 detected invalid prediction
# 280 detected invalid prediction
# 281 detected invalid prediction
# 282 detected invalid prediction
# 283 detected invalid prediction
# 284 detected invalid prediction
# 285 detected invalid prediction
# 286 detected invalid prediction
# 287 detected invalid prediction
# 288 detected invalid prediction
# 289 detected invalid prediction
# 290 detected invalid prediction
# 291 detected invalid prediction
# 292 detected invalid prediction
# 293 detected invalid prediction
# 294 detected invalid prediction
# 295 detected invalid prediction
# 296 detected invalid prediction
# 297 detected invalid prediction
# 298 detected invalid prediction
# 299 detected invalid prediction
# 300 detected invalid prediction
# 301 detected invalid prediction
# 302 detected invalid prediction
# 303 detected invalid prediction
# 304 detected invalid prediction
# 305 detected invalid prediction
# 306 detected invalid prediction
# 307 detected invalid prediction
# 308 detected invalid prediction
# 309 detected invalid prediction
# 310 detected invalid prediction
# 311 detected invalid prediction
# 312 detected invalid prediction
# 313 detected invalid prediction
# 314 detected invalid prediction
# 315 detected invalid prediction
# 316 detected invalid prediction
# 317 detected invalid prediction
# 318 detected invalid prediction
# 319 detected invalid prediction
# 320 detected invalid prediction
# 321 detected invalid prediction
# 322 detected invalid prediction
# 323 detected invalid prediction
# 324 detected invalid prediction
# 325 detected invalid prediction
# 326 detected invalid prediction
# 327 detected invalid prediction
# 328 detected invalid prediction
# 329 detected invalid prediction
# 330 detected invalid prediction
# 331 detected invalid prediction
# 332 detected invalid prediction
# 333 detected invalid prediction
# 334 detected invalid prediction
# 335 detected invalid prediction
# 336 detected invalid prediction
# 337 detected invalid prediction
# 338 detected invalid prediction
# 339 detected invalid prediction
# 340 detected invalid prediction
# 341 detected invalid prediction
# 342 detected invalid prediction
# 343 detected invalid prediction
# 344 detected invalid prediction
# 345 detected invalid prediction
# 346 detected invalid prediction
# 347 detected invalid prediction
# 348 detected invalid prediction
# 349 detected invalid prediction
# 350 detected invalid prediction
# 351 detected invalid prediction
# 352 detected invalid prediction
# 353 detected invalid prediction
# 354 detected invalid prediction
# 355 detected invalid prediction
# 356 detected invalid prediction
# 357 detected invalid prediction
# 358 detected invalid prediction
# 359 detected invalid prediction
# 360 detected invalid prediction
# 361 detected invalid prediction
# 362 detected invalid prediction
# 363 detected invalid prediction
# 364 detected invalid prediction
# 365 detected invalid prediction
# 366 detected invalid prediction
# 367 detected invalid prediction
# 368 detected invalid prediction
# 369 detected invalid prediction
# 370 detected invalid prediction
# 371 detected invalid prediction
# 372 detected invalid prediction
# 373 detected invalid prediction
# 374 detected invalid prediction
# 375 detected invalid prediction
# 376 detected invalid prediction
# 377 detected invalid prediction
# 378 detected invalid prediction
# 379 detected invalid prediction
# 380 detected invalid prediction
# 381 detected invalid prediction
# 382 detected invalid prediction
# 383 detected invalid prediction
# 384 detected invalid prediction
# 385 detected invalid prediction
# 386 detected invalid prediction
# 387 detected invalid prediction
# 388 detected invalid prediction
# 389 detected invalid prediction
# 390 detected invalid prediction
# 391 detected invalid prediction
# 392 detected invalid prediction
# 393 detected invalid prediction
# 394 detected invalid prediction
# 395 detected invalid prediction
# 396 detected invalid prediction
# 397 detected invalid prediction
# 398 detected invalid prediction
# 399 detected invalid prediction
# 400 detected invalid prediction
# 401 detected invalid prediction
# 402 detected invalid prediction
# 403 detected invalid prediction
# 404 detected invalid prediction
# 405 detected invalid prediction
# 406 detected invalid prediction
# 407 detected invalid prediction
# 408 detected invalid prediction
# 409 detected invalid prediction
# 410 detected invalid prediction
# 411 detected invalid prediction
# 412 detected invalid prediction
# 413 detected invalid prediction
# 414 detected invalid prediction
# 415 detected invalid prediction
# 416 detected invalid prediction
# 417 detected invalid prediction
# 418 detected invalid prediction
# 419 detected invalid prediction
# 420 detected invalid prediction
# 421 detected invalid prediction
# 422 detected invalid prediction
# 423 detected invalid prediction
# 424 detected invalid prediction
# 425 detected invalid prediction
# 426 detected invalid prediction
# 427 detected invalid prediction
# 428 detected invalid prediction
# 429 detected invalid prediction
# 430 detected invalid prediction
# 431 detected invalid prediction
# 432 detected invalid prediction
# 433 detected invalid prediction
# 434 detected invalid prediction
# 435 detected invalid prediction
# 436 detected invalid prediction
# 437 detected invalid prediction
# 438 detected invalid prediction
# 439 detected invalid prediction
# 440 detected invalid prediction
# 441 detected invalid prediction
# 442 detected invalid prediction
# 443 detected invalid prediction
# 444 detected invalid prediction
# 445 detected invalid prediction
# 446 detected invalid prediction
# 447 detected invalid prediction
# 448 detected invalid prediction
# 449 detected invalid prediction
# 450 detected invalid prediction
# 451 detected invalid prediction
# 452 detected invalid prediction
# 453 detected invalid prediction
# 454 detected invalid prediction
# 455 detected invalid prediction
# 456 detected invalid prediction
# 457 detected invalid prediction
# 458 detected invalid prediction
# 459 detected invalid prediction
# 460 detected invalid prediction
# 461 detected invalid prediction
# 462 detected invalid prediction
# 463 detected invalid prediction
# 464 detected invalid prediction
# 465 detected invalid prediction
# 466 detected invalid prediction
# 467 detected invalid prediction
# 468 detected invalid prediction
# 469 detected invalid prediction
# 470 detected invalid prediction
# 471 detected invalid prediction
# 472 detected invalid prediction
# 473 detected invalid prediction
# 474 detected invalid prediction
# 475 detected invalid prediction
# 476 detected invalid prediction
# 477 detected invalid prediction
# 478 detected invalid prediction
# 479 detected invalid prediction
# 480 detected invalid prediction
# 481 detected invalid prediction
# 482 detected invalid prediction
# 483 detected invalid prediction
# 484 detected invalid prediction
# 485 detected invalid prediction
# 486 detected invalid prediction
# 487 detected invalid prediction
# 488 detected invalid prediction
# 489 detected invalid prediction
# 490 detected invalid prediction
# 491 detected invalid prediction
# 492 detected invalid prediction
# 493 detected invalid prediction
# 494 detected invalid prediction
# 495 detected invalid prediction
# 496 detected invalid prediction
# 497 detected invalid prediction
# 498 detected invalid prediction
# 499 detected invalid prediction
# 500 detected invalid prediction
# 501 detected invalid prediction
# 502 detected invalid prediction
# 503 detected invalid prediction
# 504 detected invalid prediction
# 505 detected invalid prediction
# 506 detected invalid prediction
# 507 detected invalid prediction
# 508 detected invalid prediction
# 509 detected invalid prediction
# 510 detected invalid prediction
# 511 detected invalid prediction
# 512 detected invalid prediction
# 513 detected invalid prediction
# 514 detected invalid prediction
# 515 detected invalid prediction
# 516 detected invalid prediction
# 517 detected invalid prediction
# 518 detected invalid prediction
# 519 detected invalid prediction
# 520 detected invalid prediction
# 521 detected invalid prediction
# 522 detected invalid prediction
# 523 detected invalid prediction
# 524 detected invalid prediction
# 525 detected invalid prediction
# 526 detected invalid prediction
# 527 detected invalid prediction
# 528 detected invalid prediction
# 529 detected invalid prediction
# 530 detected invalid prediction
# 531 detected invalid prediction
# 532 detected invalid prediction
# 533 detected invalid prediction
# 534 detected invalid prediction
# 535 detected invalid prediction
# 536 detected invalid prediction
# 537 detected invalid prediction
# 538 detected invalid prediction
# 539 detected invalid prediction
# 540 detected invalid prediction
# 541 detected invalid prediction
# 542 detected invalid prediction
# 543 detected invalid prediction
# 544 detected invalid prediction
# 545 detected invalid prediction
# 546 detected invalid prediction
# 547 detected invalid prediction
# 548 detected invalid prediction
# 549 detected invalid prediction
# 550 detected invalid prediction
# 551 detected invalid prediction
# 552 detected invalid prediction
# 553 detected invalid prediction
# 554 detected invalid prediction
# 555 detected invalid prediction
# 556 detected invalid prediction
# 557 detected invalid prediction
# 558 detected invalid prediction
# 559 detected invalid prediction
# 560 detected invalid prediction
# 561 detected invalid prediction
# 562 detected invalid prediction
# 563 detected invalid prediction
# 564 detected invalid prediction
# 565 detected invalid prediction
# 566 detected invalid prediction
# 567 detected invalid prediction
# 568 detected invalid prediction
# 569 detected invalid prediction
# 570 detected invalid prediction
# 571 detected invalid prediction
# 572 detected invalid prediction
# 573 detected invalid prediction
# 574 detected invalid prediction
# 575 detected invalid prediction
# 576 detected invalid prediction
# 577 detected invalid prediction
# 578 detected invalid prediction
# 579 detected invalid prediction
# 580 detected invalid prediction
# 581 detected invalid prediction
# 582 detected invalid prediction
# 583 detected invalid prediction
# 584 detected invalid prediction
# 585 detected invalid prediction
# 586 detected invalid prediction
# 587 detected invalid prediction
# 588 detected invalid prediction
# 589 detected invalid prediction
# 590 detected invalid prediction
# 591 detected invalid prediction
# 592 detected invalid prediction
# 593 detected invalid prediction
# 594 detected invalid prediction
# 595 detected invalid prediction
# 596 detected invalid prediction
# 597 detected invalid prediction
# 598 detected invalid prediction
# 599 detected invalid prediction
# 600 detected invalid prediction
# 601 detected invalid prediction
# 602 detected invalid prediction
# 603 detected invalid prediction
# 604 detected invalid prediction
# 605 detected invalid prediction
# 606 detected invalid prediction
# 607 detected invalid prediction
# 608 detected invalid prediction
# 609 detected invalid prediction
# 610 detected invalid prediction
# 611 detected invalid prediction
# 612 detected invalid prediction
# 613 detected invalid prediction
# 614 detected invalid prediction
# 615 detected invalid prediction
# 616 detected invalid prediction
# 617 detected invalid prediction
# 618 detected invalid prediction
# 619 detected invalid prediction
# 620 detected invalid prediction
# 621 detected invalid prediction
# 622 detected invalid prediction
# 623 detected invalid prediction
# 624 detected invalid prediction
# 625 detected invalid prediction
# 626 detected invalid prediction
# 627 detected invalid prediction
# 628 detected invalid prediction
# 629 detected invalid prediction
# 630 detected invalid prediction
# 631 detected invalid prediction
# 632 detected invalid prediction
# 633 detected invalid prediction
# 634 detected invalid prediction
# 635 detected invalid prediction
# 636 detected invalid prediction
# 637 detected invalid prediction
# 638 detected invalid prediction
# 639 detected invalid prediction
# 640 detected invalid prediction
# 641 detected invalid prediction
# 642 detected invalid prediction
# 643 detected invalid prediction
# 644 detected invalid prediction
# 645 detected invalid prediction
# 646 detected invalid prediction
# 647 detected invalid prediction
# 648 detected invalid prediction
# 649 detected invalid prediction
# 650 detected invalid prediction
# 651 detected invalid prediction
# 652 detected invalid prediction
# 653 detected invalid prediction
# 654 detected invalid prediction
# 655 detected invalid prediction
# 656 detected invalid prediction
# 657 detected invalid prediction
# 658 detected invalid prediction
# 659 detected invalid prediction
# 660 detected invalid prediction
# 661 detected invalid prediction
# 662 detected invalid prediction
# 663 detected invalid prediction
# 664 detected invalid prediction
# 665 detected invalid prediction
# 666 detected invalid prediction
# 667 detected invalid prediction
# 668 detected invalid prediction
# 669 detected invalid prediction
# 670 detected invalid prediction
# 671 detected invalid prediction
# 672 detected invalid prediction
# 673 detected invalid prediction
# 674 detected invalid prediction
# 675 detected invalid prediction
# 676 detected invalid prediction
# 677 detected invalid prediction
# 678 detected invalid prediction
# 679 detected invalid prediction
# 680 detected invalid prediction
# 681 detected invalid prediction
# 682 detected invalid prediction
# 683 detected invalid prediction
# 684 detected invalid prediction
# 685 detected invalid prediction
# 686 detected invalid prediction
# 687 detected invalid prediction
# 688 detected invalid prediction
# 689 detected invalid prediction
# 690 detected invalid prediction
# 691 detected invalid prediction
# 692 detected invalid prediction
# 693 detected invalid prediction
# 694 detected invalid prediction
# 695 detected invalid prediction
# 696 detected invalid prediction
# 697 detected invalid prediction
# 698 detected invalid prediction
# 699 detected invalid prediction
# 700 detected invalid prediction
# 701 detected invalid prediction
# 702 detected invalid prediction
# 703 detected invalid prediction
# 704 detected invalid prediction
# 705 detected invalid prediction
# 706 detected invalid prediction
# 707 detected invalid prediction
# 708 detected invalid prediction
# 709 detected invalid prediction
# 710 detected invalid prediction
# 711 detected invalid prediction
# 712 detected invalid prediction
# 713 detected invalid prediction
# 714 detected invalid prediction
# 715 detected invalid prediction
# 716 detected invalid prediction
# 717 detected invalid prediction
# 718 detected invalid prediction
# 719 detected invalid prediction
# 720 detected invalid prediction
# 721 detected invalid prediction
# 722 detected invalid prediction
# 723 detected invalid prediction
# 724 detected invalid prediction
# 725 detected invalid prediction
# 726 detected invalid prediction
# 727 detected invalid prediction
# 728 detected invalid prediction
# 729 detected invalid prediction
# 730 detected invalid prediction
# 731 detected invalid prediction
# 732 detected invalid prediction
# 733 detected invalid prediction
# 734 detected invalid prediction
# 735 detected invalid prediction
# 736 detected invalid prediction
# 737 detected invalid prediction
# 738 detected invalid prediction
# 739 detected invalid prediction
# 740 detected invalid prediction
# 741 detected invalid prediction
# 742 detected invalid prediction
# 743 detected invalid prediction
# 744 detected invalid prediction
# 745 detected invalid prediction
# 746 detected invalid prediction
# 747 detected invalid prediction
# 748 detected invalid prediction
# 749 detected invalid prediction
# 750 detected invalid prediction
# 751 detected invalid prediction
# 752 detected invalid prediction
# 753 detected invalid prediction
# 754 detected invalid prediction
# 755 detected invalid prediction
# 756 detected invalid prediction
# 757 detected invalid prediction
# 758 detected invalid prediction
# 759 detected invalid prediction
# 760 detected invalid prediction
# 761 detected invalid prediction
# 762 detected invalid prediction
# 763 detected invalid prediction
# 764 detected invalid prediction
# 765 detected invalid prediction
# 766 detected invalid prediction
# 767 detected invalid prediction
# 768 detected invalid prediction
# 769 detected invalid prediction
# 770 detected invalid prediction
# 771 detected invalid prediction
# 772 detected invalid prediction
# 773 detected invalid prediction
# 774 detected invalid prediction
# 775 detected invalid prediction
# 776 detected invalid prediction
# 777 detected invalid prediction
# 778 detected invalid prediction
# 779 detected invalid prediction
# 780 detected invalid prediction
# 781 detected invalid prediction
# 782 detected invalid prediction
# 783 detected invalid prediction
# 784 detected invalid prediction
# 785 detected invalid prediction
# 786 detected invalid prediction
# 787 detected invalid prediction
# 788 detected invalid prediction
# 789 detected invalid prediction
# 790 detected invalid prediction
# 791 detected invalid prediction
# 792 detected invalid prediction
# 793 detected invalid prediction
# 794 detected invalid prediction
# 795 detected invalid prediction
# 796 detected invalid prediction
# 797 detected invalid prediction
# 798 detected invalid prediction
# 799 detected invalid prediction
# 800 detected invalid prediction
# 801 detected invalid prediction
# 802 detected invalid prediction
# 803 detected invalid prediction
# 804 detected invalid prediction
# 805 detected invalid prediction
# 806 detected invalid prediction
# 807 detected invalid prediction
# 808 detected invalid prediction
# 809 detected invalid prediction
# 810 detected invalid prediction
# 811 detected invalid prediction
# 812 detected invalid prediction
# 813 detected invalid prediction
# 814 detected invalid prediction
# 815 detected invalid prediction
# 816 detected invalid prediction
# 817 detected invalid prediction
# 818 detected invalid prediction
# 819 detected invalid prediction
# 820 detected invalid prediction
# 821 detected invalid prediction
# 822 detected invalid prediction
# 823 detected invalid prediction
# 824 detected invalid prediction
# 825 detected invalid prediction
# 826 detected invalid prediction
# 827 detected invalid prediction
# 828 detected invalid prediction
# 829 detected invalid prediction
# 830 detected invalid prediction
# 831 detected invalid prediction
# 832 detected invalid prediction
# 833 detected invalid prediction
# 834 detected invalid prediction
# 835 detected invalid prediction
# 836 detected invalid prediction
# 837 detected invalid prediction
# 838 detected invalid prediction
# 839 detected invalid prediction
# 840 detected invalid prediction
# 841 detected invalid prediction
# 842 detected invalid prediction
# 843 detected invalid prediction
# 844 detected invalid prediction
# 845 detected invalid prediction
# 846 detected invalid prediction
# 847 detected invalid prediction
# 848 detected invalid prediction
# 849 detected invalid prediction
# 850 detected invalid prediction
# 851 detected invalid prediction
# 852 detected invalid prediction
# 853 detected invalid prediction
# 854 detected invalid prediction
# 855 detected invalid prediction
# 856 detected invalid prediction
# 857 detected invalid prediction
# 858 detected invalid prediction
# 859 detected invalid prediction
# 860 detected invalid prediction
# 861 detected invalid prediction
# 862 detected invalid prediction
# 863 detected invalid prediction
# 864 detected invalid prediction
# 865 detected invalid prediction
# 866 detected invalid prediction
# 867 detected invalid prediction
# 868 detected invalid prediction
# 869 detected invalid prediction
# 870 detected invalid prediction
# 871 detected invalid prediction
# 872 detected invalid prediction
# 873 detected invalid prediction
# 874 detected invalid prediction
# 875 detected invalid prediction
# 876 detected invalid prediction
# 877 detected invalid prediction
# 878 detected invalid prediction
# 879 detected invalid prediction
# 880 detected invalid prediction
# 881 detected invalid prediction
# 882 detected invalid prediction
# 883 detected invalid prediction
# 884 detected invalid prediction
# 885 detected invalid prediction
# 886 detected invalid prediction
# 887 detected invalid prediction
# 888 detected invalid prediction
# 889 detected invalid prediction
# 890 detected invalid prediction
# 891 detected invalid prediction
# 892 detected invalid prediction
# 893 detected invalid prediction
# 894 detected invalid prediction
# 895 detected invalid prediction
# 896 detected invalid prediction
# 897 detected invalid prediction
# 898 detected invalid prediction
# 899 detected invalid prediction
# 900 detected invalid prediction
# 901 detected invalid prediction
# 902 detected invalid prediction
# 903 detected invalid prediction
# 904 detected invalid prediction
# 905 detected invalid prediction
# 906 detected invalid prediction
# 907 detected invalid prediction
# 908 detected invalid prediction
# 909 detected invalid prediction
# 910 detected invalid prediction
# 911 detected invalid prediction
# 912 detected invalid prediction
# 913 detected invalid prediction
# 914 detected invalid prediction
# 915 detected invalid prediction
# 916 detected invalid prediction
# 917 detected invalid prediction
# 918 detected invalid prediction
# 919 detected invalid prediction
# 920 detected invalid prediction
# 921 detected invalid prediction
# 922 detected invalid prediction
# 923 detected invalid prediction
# 924 detected invalid prediction
# 925 detected invalid prediction
# 926 detected invalid prediction
# 927 detected invalid prediction
# 928 detected invalid prediction
# 929 detected invalid prediction
# 930 detected invalid prediction
# 931 detected invalid prediction
# 932 detected invalid prediction
# 933 detected invalid prediction
# 934 detected invalid prediction
# 935 detected invalid prediction
# 936 detected invalid prediction
# 937 detected invalid prediction
# 938 detected invalid prediction
# 939 detected invalid prediction
# 940 detected invalid prediction
# 941 detected invalid prediction
# 942 detected invalid prediction
# 943 detected invalid prediction
# 944 detected invalid prediction
# 945 detected invalid prediction
# 946 detected invalid prediction
# 947 detected invalid prediction
# 948 detected invalid prediction
# 949 detected invalid prediction
# 950 detected invalid prediction
# 951 detected invalid prediction
# 952 detected invalid prediction
# 953 detected invalid prediction
# 954 detected invalid prediction
# 955 detected invalid prediction
# 956 detected invalid prediction
# 957 detected invalid prediction
# 958 detected invalid prediction
# 959 detected invalid prediction
# 960 detected invalid prediction
# 961 detected invalid prediction
# 962 detected invalid prediction
# 963 detected invalid prediction
# 964 detected invalid prediction
# 965 detected invalid prediction
# 966 detected invalid prediction
# 967 detected invalid prediction
# 968 detected invalid prediction
# 969 detected invalid prediction
# 970 detected invalid prediction
# 971 detected invalid prediction
# 972 detected invalid prediction
# 973 detected invalid prediction
# 974 detected invalid prediction
# 975 detected invalid prediction
# 976 detected invalid prediction
# 977 detected invalid prediction
# 978 detected invalid prediction
# 979 detected invalid prediction
# 980 detected invalid prediction
# 981 detected invalid prediction
# 982 detected invalid prediction
# 983 detected invalid prediction
# 984 detected invalid prediction
# 985 detected invalid prediction
# 986 detected invalid prediction
# 987 detected invalid prediction
# 988 detected invalid prediction
# 989 detected invalid prediction
# 990 detected invalid prediction
# 991 detected invalid prediction
# 992 detected invalid prediction
# 993 detected invalid prediction
# 994 detected invalid prediction
# 995 detected invalid prediction
# 996 detected invalid prediction
# 997 detected invalid prediction
# 998 detected invalid prediction
# 999 detected invalid prediction
# 1000 detected invalid prediction
# 1001 detected invalid prediction
# 1002 detected invalid prediction
# 1003 detected invalid prediction
# 1004 detected invalid prediction
# 1005 detected invalid prediction
# 1006 detected invalid prediction
# 1007 detected invalid prediction
# 1008 detected invalid prediction
# 1009 detected invalid prediction
# 1010 detected invalid prediction
# 1011 detected invalid prediction
# 1012 detected invalid prediction
# 1013 detected invalid prediction
# 1014 detected invalid prediction
# 1015 detected invalid prediction
# 1016 detected invalid prediction
# 1017 detected invalid prediction
# 1018 detected invalid prediction
# 1019 detected invalid prediction
# 1020 detected invalid prediction
# 1021 detected invalid prediction
# 1022 detected invalid prediction
# 1023 detected invalid prediction
# 1024 detected invalid prediction
# 1025 detected invalid prediction
# 1026 detected invalid prediction
# 1027 detected invalid prediction
# 1028 detected invalid prediction
# 1029 detected invalid prediction
# 1030 detected invalid prediction
# 1031 detected invalid prediction
# 1032 detected invalid prediction
# 1033 detected invalid prediction
# 1034 detected invalid prediction
# 1035 detected invalid prediction
# 1036 detected invalid prediction
# 1037 detected invalid prediction
# 1038 detected invalid prediction
# 1039 detected invalid prediction
# 1040 detected invalid prediction
# 1041 detected invalid prediction
# 1042 detected invalid prediction
# 1043 detected invalid prediction
# 1044 detected invalid prediction
# 1045 detected invalid prediction
# 1046 detected invalid prediction
# 1047 detected invalid prediction
# 1048 detected invalid prediction
# 1049 detected invalid prediction
# 1050 detected invalid prediction
# 1051 detected invalid prediction
# 1052 detected invalid prediction
# 1053 detected invalid prediction
# 1054 detected invalid prediction
# 1055 detected invalid prediction
# 1056 detected invalid prediction
# 1057 detected invalid prediction
# 1058 detected invalid prediction
# 1059 detected invalid prediction
# 1060 detected invalid prediction
# 1061 detected invalid prediction
# 1062 detected invalid prediction
# 1063 detected invalid prediction
# 1064 detected invalid prediction
# 1065 detected invalid prediction
# 1066 detected invalid prediction
# 1067 detected invalid prediction
# 1068 detected invalid prediction
# 1069 detected invalid prediction
# 1070 detected invalid prediction
# 1071 detected invalid prediction
# 1072 detected invalid prediction
# 1073 detected invalid prediction
# 1074 detected invalid prediction
# 1075 detected invalid prediction
# 1076 detected invalid prediction
# 1077 detected invalid prediction
# 1078 detected invalid prediction
# 1079 detected invalid prediction
# 1080 detected invalid prediction
# 1081 detected invalid prediction
# 1082 detected invalid prediction
# 1083 detected invalid prediction
# 1084 detected invalid prediction
# 1085 detected invalid prediction
# 1086 detected invalid prediction
# 1087 detected invalid prediction
# 1088 detected invalid prediction
# 1089 detected invalid prediction
# 1090 detected invalid prediction
# 1091 detected invalid prediction
# 1092 detected invalid prediction
# 1093 detected invalid prediction
# 1094 detected invalid prediction
# 1095 detected invalid prediction
# 1096 detected invalid prediction
# 1097 detected invalid prediction
# 1098 detected invalid prediction
# 1099 detected invalid prediction
# 1100 detected invalid prediction
# 1101 detected invalid prediction
# 1102 detected invalid prediction
# 1103 detected invalid prediction
# 1104 detected invalid prediction
# 1105 detected invalid prediction
# 1106 detected invalid prediction
# 1107 detected invalid prediction
# 1108 detected invalid prediction
# 1109 detected invalid prediction
# 1110 detected invalid prediction
# 1111 detected invalid prediction
# 1112 detected invalid prediction
# 1113 detected invalid prediction
# 1114 detected invalid prediction
# 1115 detected invalid prediction
# 1116 detected invalid prediction
# 1117 detected invalid prediction
# 1118 detected invalid prediction
# 1119 detected invalid prediction
# 1120 detected invalid prediction
# 1121 detected invalid prediction
# 1122 detected invalid prediction
# 1123 detected invalid prediction
# 1124 detected invalid prediction
# 1125 detected invalid prediction
# 1126 detected invalid prediction
# 1127 detected invalid prediction
# 1128 detected invalid prediction
# 1129 detected invalid prediction
# 1130 detected invalid prediction
# 1131 detected invalid prediction
# 1132 detected invalid prediction
# 1133 detected invalid prediction
# 1134 detected invalid prediction
# 1135 detected invalid prediction
# 1136 detected invalid prediction
# 1137 detected invalid prediction
# 1138 detected invalid prediction
# 1139 detected invalid prediction
# 1140 detected invalid prediction
# 1141 detected invalid prediction
# 1142 detected invalid prediction
# 1143 detected invalid prediction
# 1144 detected invalid prediction
# 1145 detected invalid prediction
# 1146 detected invalid prediction
# 1147 detected invalid prediction
# 1148 detected invalid prediction
# 1149 detected invalid prediction
# 1150 detected invalid prediction
# 1151 detected invalid prediction
# 1152 detected invalid prediction
# 1153 detected invalid prediction
# 1154 detected invalid prediction
# 1155 detected invalid prediction
# 1156 detected invalid prediction
# 1157 detected invalid prediction
# 1158 detected invalid prediction
# 1159 detected invalid prediction
# 1160 detected invalid prediction
# 1161 detected invalid prediction
# 1162 detected invalid prediction
# 1163 detected invalid prediction
# 1164 detected invalid prediction
# 1165 detected invalid prediction
# 1166 detected invalid prediction
# 1167 detected invalid prediction
# 1168 detected invalid prediction
# 1169 detected invalid prediction
# 1170 detected invalid prediction
# 1171 detected invalid prediction
# 1172 detected invalid prediction
# 1173 detected invalid prediction
# 1174 detected invalid prediction
# 1175 detected invalid prediction
# 1176 detected invalid prediction
# 1177 detected invalid prediction
# 1178 detected invalid prediction
# 1179 detected invalid prediction
# 1180 detected invalid prediction
# 1181 detected invalid prediction
# 1182 detected invalid prediction
# 1183 detected invalid prediction
# 1184 detected invalid prediction
# 1185 detected invalid prediction
# 1186 detected invalid prediction
# 1187 detected invalid prediction
# 1188 detected invalid prediction
# 1189 detected invalid prediction
# 1190 detected invalid prediction
# 1191 detected invalid prediction
# 1192 detected invalid prediction
# 1193 detected invalid prediction
# 1194 detected invalid prediction
# 1195 detected invalid prediction
# 1196 detected invalid prediction
# 1197 detected invalid prediction
# 1198 detected invalid prediction
# 1199 detected invalid prediction
# 1200 detected invalid prediction
# 1201 detected invalid prediction
# 1202 detected invalid prediction
# 1203 detected invalid prediction
# 1204 detected invalid prediction
# 1205 detected invalid prediction
# 1206 detected invalid prediction
# 1207 detected invalid prediction
# 1208 detected invalid prediction
# 1209 detected invalid prediction
# 1210 detected invalid prediction
# 1211 detected invalid prediction
# 1212 detected invalid prediction
# 1213 detected invalid prediction
# 1214 detected invalid prediction
# 1215 detected invalid prediction
# 1216 detected invalid prediction
# 1217 detected invalid prediction
# 1218 detected invalid prediction
# 1219 detected invalid prediction
# 1220 detected invalid prediction
# 1221 detected invalid prediction
# 1222 detected invalid prediction
# 1223 detected invalid prediction
# 1224 detected invalid prediction
# 1225 detected invalid prediction
# 1226 detected invalid prediction
# 1227 detected invalid prediction
# 1228 detected invalid prediction
# 1229 detected invalid prediction
# 1230 detected invalid prediction
# 1231 detected invalid prediction
# 1232 detected invalid prediction
# 1233 detected invalid prediction
# 1234 detected invalid prediction
# 1235 detected invalid prediction
# 1236 detected invalid prediction
# 1237 detected invalid prediction
# 1238 detected invalid prediction
# 1239 detected invalid prediction
# 1240 detected invalid prediction
# 1241 detected invalid prediction
# 1242 detected invalid prediction
# 1243 detected invalid prediction
# 1244 detected invalid prediction
# 1245 detected invalid prediction
# 1246 detected invalid prediction
# 1247 detected invalid prediction
# 1248 detected invalid prediction
# 1249 detected invalid prediction
# 1250 detected invalid prediction
# 1251 detected invalid prediction
# 1252 detected invalid prediction
# 1253 detected invalid prediction
# 1254 detected invalid prediction
# 1255 detected invalid prediction
# 1256 detected invalid prediction
# 1257 detected invalid prediction
# 1258 detected invalid prediction
# 1259 detected invalid prediction
# 1260 detected invalid prediction
# 1261 detected invalid prediction
# 1262 detected invalid prediction
# 1263 detected invalid prediction
# 1264 detected invalid prediction
# 1265 detected invalid prediction
# 1266 detected invalid prediction
# 1267 detected invalid prediction
# 1268 detected invalid prediction
# 1269 detected invalid prediction
# 1270 detected invalid prediction
# 1271 detected invalid prediction
# 1272 detected invalid prediction
# 1273 detected invalid prediction
# 1274 detected invalid prediction
# 1275 detected invalid prediction
# 1276 detected invalid prediction
# 1277 detected invalid prediction
# 1278 detected invalid prediction
# 1279 detected invalid prediction
# 1280 detected invalid prediction
# 1281 detected invalid prediction
# 1282 detected invalid prediction
# 1283 detected invalid prediction
# 1284 detected invalid prediction
# 1285 detected invalid prediction
# 1286 detected invalid prediction
# 1287 detected invalid prediction
# 1288 detected invalid prediction
# 1289 detected invalid prediction
# 1290 detected invalid prediction
# 1291 detected invalid prediction
# 1292 detected invalid prediction
# 1293 detected invalid prediction
# 1294 detected invalid prediction
# 1295 detected invalid prediction
# 1296 detected invalid prediction
# 1297 detected invalid prediction
# 1298 detected invalid prediction
# 1299 detected invalid prediction
# 1300 detected invalid prediction
# 1301 detected invalid prediction
# 1302 detected invalid prediction
# 1303 detected invalid prediction
# 1304 detected invalid prediction
# 1305 detected invalid prediction
# 1306 detected invalid prediction
# 1307 detected invalid prediction
# 1308 detected invalid prediction
# 1309 detected invalid prediction
# 1310 detected invalid prediction
# 1311 detected invalid prediction
# 1312 detected invalid prediction
# 1313 detected invalid prediction
# 1314 detected invalid prediction
# 1315 detected invalid prediction
# 1316 detected invalid prediction
# 1317 detected invalid prediction
# 1318 detected invalid prediction
# 1319 detected invalid prediction
# 1320 detected invalid prediction
# 1321 detected invalid prediction
# 1322 detected invalid prediction
# 1323 detected invalid prediction
# 1324 detected invalid prediction
# 1325 detected invalid prediction
# 1326 detected invalid prediction
# 1327 detected invalid prediction
# 1328 detected invalid prediction
# 1329 detected invalid prediction
# 1330 detected invalid prediction
# 1331 detected invalid prediction
# 1332 detected invalid prediction
# 1333 detected invalid prediction
# 1334 detected invalid prediction
# 1335 detected invalid prediction
# 1336 detected invalid prediction
# 1337 detected invalid prediction
# 1338 detected invalid prediction
# 1339 detected invalid prediction
# 1340 detected invalid prediction
# 1341 detected invalid prediction
# 1342 detected invalid prediction
# 1343 detected invalid prediction
# 1344 detected invalid prediction
# 1345 detected invalid prediction
# 1346 detected invalid prediction
# 1347 detected invalid prediction
# 1348 detected invalid prediction
# 1349 detected invalid prediction
# 1350 detected invalid prediction
# 1351 detected invalid prediction
# 1352 detected invalid prediction
# 1353 detected invalid prediction
# 1354 detected invalid prediction
# 1355 detected invalid prediction
# 1356 detected invalid prediction
# 1357 detected invalid prediction
# 1358 detected invalid prediction
# 1359 detected invalid prediction
# 1360 detected invalid prediction
# 1361 detected invalid prediction
# 1362 detected invalid prediction
# 1363 detected invalid prediction
# 1364 detected invalid prediction
# 1365 detected invalid prediction
# 1366 detected invalid prediction
# 1367 detected invalid prediction
# 1368 detected invalid prediction
# 1369 detected invalid prediction
# 1370 detected invalid prediction
# 1371 detected invalid prediction
# 1372 detected invalid prediction
# 1373 detected invalid prediction
# 1374 detected invalid prediction
# 1375 detected invalid prediction
# 1376 detected invalid prediction
# 1377 detected invalid prediction
# 1378 detected invalid prediction
# 1379 detected invalid prediction
# 1380 detected invalid prediction
# 1381 detected invalid prediction
# 1382 detected invalid prediction
# 1383 detected invalid prediction
# 1384 detected invalid prediction
# 1385 detected invalid prediction
# 1386 detected invalid prediction
# 1387 detected invalid prediction
# 1388 detected invalid prediction
# 1389 detected invalid prediction
# 1390 detected invalid prediction
# 1391 detected invalid prediction
# 1392 detected invalid prediction
# 1393 detected invalid prediction
# 1394 detected invalid prediction
# 1395 detected invalid prediction
# 1396 detected invalid prediction
# 1397 detected invalid prediction
# 1398 detected invalid prediction
# 1399 detected invalid prediction
# 1400 detected invalid prediction
# 1401 detected invalid prediction
# 1402 detected invalid prediction
# 1403 detected invalid prediction
# 1404 detected invalid prediction
# 1405 detected invalid prediction
# 1406 detected invalid prediction
# 1407 detected invalid prediction
# 1408 detected invalid prediction
# 1409 detected invalid prediction
# 1410 detected invalid prediction
# 1411 detected invalid prediction
# 1412 detected invalid prediction
# 1413 detected invalid prediction
# 1414 detected invalid prediction
# 1415 detected invalid prediction
# 1416 detected invalid prediction
# 1417 detected invalid prediction
# 1418 detected invalid prediction
# 1419 detected invalid prediction
# 1420 detected invalid prediction
# 1421 detected invalid prediction
# 1422 detected invalid prediction
# 1423 detected invalid prediction
# 1424 detected invalid prediction
# 1425 detected invalid prediction
# 1426 detected invalid prediction
# 1427 detected invalid prediction
# 1428 detected invalid prediction
# 1429 detected invalid prediction
# 1430 detected invalid prediction
# 1431 detected invalid prediction
# 1432 detected invalid prediction
# 1433 detected invalid prediction
# 1434 detected invalid prediction
# 1435 detected invalid prediction
# 1436 detected invalid prediction
# 1437 detected invalid prediction
# 1438 detected invalid prediction
# 1439 detected invalid prediction
# 1440 detected invalid prediction
# 1441 detected invalid prediction
# 1442 detected invalid prediction
# 1443 detected invalid prediction
# 1444 detected invalid prediction
# 1445 detected invalid prediction
# 1446 detected invalid prediction
# 1447 detected invalid prediction
# 1448 detected invalid prediction
# 1449 detected invalid prediction
# 1450 detected invalid prediction
# 1451 detected invalid prediction
# 1452 detected invalid prediction
# 1453 detected invalid prediction
# 1454 detected invalid prediction
# 1455 detected invalid prediction
# 1456 detected invalid prediction
# 1457 detected invalid prediction
# 1458 detected invalid prediction
# 1459 detected invalid prediction
# 1460 detected invalid prediction
# 1461 detected invalid prediction
# 1462 detected invalid prediction
# 1463 detected invalid prediction
# 1464 detected invalid prediction
# 1465 detected invalid prediction
# 1466 detected invalid prediction
# 1467 detected invalid prediction
# 1468 detected invalid prediction
# 1469 detected invalid prediction
# 1470 detected invalid prediction
# 1471 detected invalid prediction
# 1472 detected invalid prediction
# 1473 detected invalid prediction
# 1474 detected invalid prediction
# 1475 detected invalid prediction
# 1476 detected invalid prediction
# 1477 detected invalid prediction
# 1478 detected invalid prediction
# 1479 detected invalid prediction
# 1480 detected invalid prediction
# 1481 detected invalid prediction
# 1482 detected invalid prediction
# 1483 detected invalid prediction
# 1484 detected invalid prediction
# 1485 detected invalid prediction
# 1486 detected invalid prediction
# 1487 detected invalid prediction
# ...
# 24530 detected invalid prediction
# 24531 detected invalid prediction
# 24532 detected invalid prediction
# 24533 detected invalid prediction
# 24534 detected invalid prediction
# 24535 detected invalid prediction
# 24536 detected invalid prediction
# 24537 detected invalid prediction
# 24538 detected invalid prediction
# 24539 detected invalid prediction
# 24540 detected invalid prediction
# 24541 detected invalid prediction
# 24542 detected invalid prediction
# 24543 detected invalid prediction
# 24544 detected invalid prediction
# 24545 detected invalid prediction
# 24546 detected invalid prediction
# 24547 detected invalid prediction
# 24548 detected invalid prediction
# 24549 detected invalid prediction
# 24550 detected invalid prediction
# 24551 detected invalid prediction
# 24552 detected invalid prediction
# 24553 detected invalid prediction
# 24554 detected invalid prediction
# 24555 detected invalid prediction
# 24556 detected invalid prediction
# 24557 detected invalid prediction
# 24558 detected invalid prediction
# 24559 detected invalid prediction
# 24560 detected invalid prediction
# 24561 detected invalid prediction
# 24562 detected invalid prediction
# 24563 detected invalid prediction
# 24564 detected invalid prediction
# 24565 detected invalid prediction
# 24566 detected invalid prediction
# 24567 detected invalid prediction
# 24568 detected invalid prediction
# 24569 detected invalid prediction
# 24570 detected invalid prediction
# 24571 detected invalid prediction
# 24572 detected invalid prediction
# 24573 detected invalid prediction
# 24574 detected invalid prediction
# 24575 detected invalid prediction
# 24576 detected invalid prediction
# 24577 detected invalid prediction
# 24578 detected invalid prediction
# 24579 detected invalid prediction
# 24580 detected invalid prediction
# 24581 detected invalid prediction
# 24582 detected invalid prediction
# 24583 detected invalid prediction
# 24584 detected invalid prediction
# 24585 detected invalid prediction
# 24586 detected invalid prediction
# 24587 detected invalid prediction
# 24588 detected invalid prediction
# 24589 detected invalid prediction
# 24590 detected invalid prediction
# 24591 detected invalid prediction
# 24592 detected invalid prediction
# 24593 detected invalid prediction
# 24594 detected invalid prediction
# 24595 detected invalid prediction
# 24596 detected invalid prediction
# 24597 detected invalid prediction
# 24598 detected invalid prediction
# 24599 detected invalid prediction
# 24600 detected invalid prediction
# 24601 detected invalid prediction
# 24602 detected invalid prediction
# 24603 detected invalid prediction
# 24604 detected invalid prediction
# 24605 detected invalid prediction
# 24606 detected invalid prediction
# 24607 detected invalid prediction
# 24608 detected invalid prediction
# 24609 detected invalid prediction
# 24610 detected invalid prediction
# 24611 detected invalid prediction
# 24612 detected invalid prediction
# 24613 detected invalid prediction
# 24614 detected invalid prediction
# 24615 detected invalid prediction
# 24616 detected invalid prediction
# 24617 detected invalid prediction
# 24618 detected invalid prediction
# 24619 detected invalid prediction
# 24620 detected invalid prediction
# 24621 detected invalid prediction
# 24622 detected invalid prediction
# 24623 detected invalid prediction
# 24624 detected invalid prediction
# 24625 detected invalid prediction
# 24626 detected invalid prediction
# 24627 detected invalid prediction
# 24628 detected invalid prediction
# 24629 detected invalid prediction
# 24630 detected invalid prediction
# 24631 detected invalid prediction
# 24632 detected invalid prediction
# 24633 detected invalid prediction
# 24634 detected invalid prediction
# 24635 detected invalid prediction
# 24636 detected invalid prediction
# 24637 detected invalid prediction
# 24638 detected invalid prediction
# 24639 detected invalid prediction
# 24640 detected invalid prediction
# 24641 detected invalid prediction
# 24642 detected invalid prediction
# 24643 detected invalid prediction
# 24644 detected invalid prediction
# 24645 detected invalid prediction
# 24646 detected invalid prediction
# 24647 detected invalid prediction
# 24648 detected invalid prediction
# 24649 detected invalid prediction
# 24650 detected invalid prediction
# 24651 detected invalid prediction
# 24652 detected invalid prediction
# 24653 detected invalid prediction
# 24654 detected invalid prediction
# 24655 detected invalid prediction
# 24656 detected invalid prediction
# 24657 detected invalid prediction
# 24658 detected invalid prediction
# 24659 detected invalid prediction
# 24660 detected invalid prediction
# 24661 detected invalid prediction
# 24662 detected invalid prediction
# 24663 detected invalid prediction
# 24664 detected invalid prediction
# 24665 detected invalid prediction
# 24666 detected invalid prediction
# 24667 detected invalid prediction
# 24668 detected invalid prediction
# 24669 detected invalid prediction
# 24670 detected invalid prediction
# 24671 detected invalid prediction
# 24672 detected invalid prediction
# 24673 detected invalid prediction
# 24674 detected invalid prediction
# 24675 detected invalid prediction
# 24676 detected invalid prediction
# 24677 detected invalid prediction
# 24678 detected invalid prediction
# 24679 detected invalid prediction
# 24680 detected invalid prediction
# 24681 detected invalid prediction
# 24682 detected invalid prediction
# 24683 detected invalid prediction
# 24684 detected invalid prediction
# 24685 detected invalid prediction
# 24686 detected invalid prediction
# 24687 detected invalid prediction
# 24688 detected invalid prediction
# 24689 detected invalid prediction
# 24690 detected invalid prediction
# 24691 detected invalid prediction
# 24692 detected invalid prediction
# 24693 detected invalid prediction
# 24694 detected invalid prediction
# 24695 detected invalid prediction
# 24696 detected invalid prediction
# 24697 detected invalid prediction
# 24698 detected invalid prediction
# 24699 detected invalid prediction
# 24700 detected invalid prediction
# 24701 detected invalid prediction
# 24702 detected invalid prediction
# 24703 detected invalid prediction
# 24704 detected invalid prediction
# 24705 detected invalid prediction
# 24706 detected invalid prediction
# 24707 detected invalid prediction
# 24708 detected invalid prediction
# 24709 detected invalid prediction
# 24710 detected invalid prediction
# 24711 detected invalid prediction
# 24712 detected invalid prediction
# 24713 detected invalid prediction
# 24714 detected invalid prediction
# 24715 detected invalid prediction
# 24716 detected invalid prediction
# 24717 detected invalid prediction
# 24718 detected invalid prediction
# 24719 detected invalid prediction
# 24720 detected invalid prediction
# 24721 detected invalid prediction
# 24722 detected invalid prediction
# 24723 detected invalid prediction
# 24724 detected invalid prediction
# 24725 detected invalid prediction
# 24726 detected invalid prediction
# 24727 detected invalid prediction
# 24728 detected invalid prediction
# 24729 detected invalid prediction
# 24730 detected invalid prediction
# 24731 detected invalid prediction
# 24732 detected invalid prediction
# 24733 detected invalid prediction
# 24734 detected invalid prediction
# 24735 detected invalid prediction
# 24736 detected invalid prediction
# 24737 detected invalid prediction
# 24738 detected invalid prediction
# 24739 detected invalid prediction
# 24740 detected invalid prediction
# 24741 detected invalid prediction
# 24742 detected invalid prediction
# 24743 detected invalid prediction
# 24744 detected invalid prediction
# 24745 detected invalid prediction
# 24746 detected invalid prediction
# 24747 detected invalid prediction
# 24748 detected invalid prediction
# 24749 detected invalid prediction
# 24750 detected invalid prediction
# 24751 detected invalid prediction
# 24752 detected invalid prediction
# 24753 detected invalid prediction
# 24754 detected invalid prediction
# 24755 detected invalid prediction
# 24756 detected invalid prediction
# 24757 detected invalid prediction
# 24758 detected invalid prediction
# 24759 detected invalid prediction
# 24760 detected invalid prediction
# 24761 detected invalid prediction
# 24762 detected invalid prediction
# 24763 detected invalid prediction
# 24764 detected invalid prediction
# 24765 detected invalid prediction
# 24766 detected invalid prediction
# 24767 detected invalid prediction
# 24768 detected invalid prediction
# 24769 detected invalid prediction
# 24770 detected invalid prediction
# 24771 detected invalid prediction
# 24772 detected invalid prediction
# 24773 detected invalid prediction
# 24774 detected invalid prediction
# 24775 detected invalid prediction
# 24776 detected invalid prediction
# 24777 detected invalid prediction
# 24778 detected invalid prediction
# 24779 detected invalid prediction
# 24780 detected invalid prediction
# 24781 detected invalid prediction
# 24782 detected invalid prediction
# 24783 detected invalid prediction
# 24784 detected invalid prediction
# 24785 detected invalid prediction
# 24786 detected invalid prediction
# 24787 detected invalid prediction
# 24788 detected invalid prediction
# 24789 detected invalid prediction
# 24790 detected invalid prediction
# 24791 detected invalid prediction
# 24792 detected invalid prediction
# 24793 detected invalid prediction
# 24794 detected invalid prediction
# 24795 detected invalid prediction
# 24796 detected invalid prediction
# 24797 detected invalid prediction
# 24798 detected invalid prediction
# 24799 detected invalid prediction
# 24800 detected invalid prediction
# 24801 detected invalid prediction
# 24802 detected invalid prediction
# 24803 detected invalid prediction
# 24804 detected invalid prediction
# 24805 detected invalid prediction
# 24806 detected invalid prediction
# 24807 detected invalid prediction
# 24808 detected invalid prediction
# 24809 detected invalid prediction
# 24810 detected invalid prediction
# 24811 detected invalid prediction
# 24812 detected invalid prediction
# 24813 detected invalid prediction
# 24814 detected invalid prediction
# 24815 detected invalid prediction
# 24816 detected invalid prediction
# 24817 detected invalid prediction
# 24818 detected invalid prediction
# 24819 detected invalid prediction
# 24820 detected invalid prediction
# 24821 detected invalid prediction
# 24822 detected invalid prediction
# 24823 detected invalid prediction
# 24824 detected invalid prediction
# 24825 detected invalid prediction
# 24826 detected invalid prediction
# 24827 detected invalid prediction
# 24828 detected invalid prediction
# 24829 detected invalid prediction
# 24830 detected invalid prediction
# 24831 detected invalid prediction
# 24832 detected invalid prediction
# 24833 detected invalid prediction
# 24834 detected invalid prediction
# 24835 detected invalid prediction
# 24836 detected invalid prediction
# 24837 detected invalid prediction
# 24838 detected invalid prediction
# 24839 detected invalid prediction
# 24840 detected invalid prediction
# 24841 detected invalid prediction
# 24842 detected invalid prediction
# 24843 detected invalid prediction
# 24844 detected invalid prediction
# 24845 detected invalid prediction
# 24846 detected invalid prediction
# 24847 detected invalid prediction
# 24848 detected invalid prediction
# 24849 detected invalid prediction
# 24850 detected invalid prediction
# 24851 detected invalid prediction
# 24852 detected invalid prediction
# 24853 detected invalid prediction
# 24854 detected invalid prediction
# 24855 detected invalid prediction
# 24856 detected invalid prediction
# 24857 detected invalid prediction
# 24858 detected invalid prediction
# 24859 detected invalid prediction
# 24860 detected invalid prediction
# 24861 detected invalid prediction
# 24862 detected invalid prediction
# 24863 detected invalid prediction
# 24864 detected invalid prediction
# 24865 detected invalid prediction
# 24866 detected invalid prediction
# 24867 detected invalid prediction
# 24868 detected invalid prediction
# 24869 detected invalid prediction
# 24870 detected invalid prediction
# 24871 detected invalid prediction
# 24872 detected invalid prediction
# 24873 detected invalid prediction
# 24874 detected invalid prediction
# 24875 detected invalid prediction
# 24876 detected invalid prediction
# 24877 detected invalid prediction
# 24878 detected invalid prediction
# 24879 detected invalid prediction
# 24880 detected invalid prediction
# 24881 detected invalid prediction
# 24882 detected invalid prediction
# 24883 detected invalid prediction
# 24884 detected invalid prediction
# 24885 detected invalid prediction
# 24886 detected invalid prediction
# 24887 detected invalid prediction
# 24888 detected invalid prediction
# 24889 detected invalid prediction
# 24890 detected invalid prediction
# 24891 detected invalid prediction
# 24892 detected invalid prediction
# 24893 detected invalid prediction
# 24894 detected invalid prediction
# 24895 detected invalid prediction
# 24896 detected invalid prediction
# 24897 detected invalid prediction
# 24898 detected invalid prediction
# 24899 detected invalid prediction
# 24900 detected invalid prediction
# 24901 detected invalid prediction
# 24902 detected invalid prediction
# 24903 detected invalid prediction
# 24904 detected invalid prediction
# 24905 detected invalid prediction
# 24906 detected invalid prediction
# 24907 detected invalid prediction
# 24908 detected invalid prediction
# 24909 detected invalid prediction
# 24910 detected invalid prediction
# 24911 detected invalid prediction
# 24912 detected invalid prediction
# 24913 detected invalid prediction
# 24914 detected invalid prediction
# 24915 detected invalid prediction
# 24916 detected invalid prediction
# 24917 detected invalid prediction
# 24918 detected invalid prediction
# 24919 detected invalid prediction
# 24920 detected invalid prediction
# 24921 detected invalid prediction
# 24922 detected invalid prediction
# 24923 detected invalid prediction
# 24924 detected invalid prediction
# 24925 detected invalid prediction
# 24926 detected invalid prediction
# 24927 detected invalid prediction
# 24928 detected invalid prediction
# 24929 detected invalid prediction
# 24930 detected invalid prediction
# 24931 detected invalid prediction
# 24932 detected invalid prediction
# 24933 detected invalid prediction
# 24934 detected invalid prediction
# 24935 detected invalid prediction
# 24936 detected invalid prediction
# 24937 detected invalid prediction
# 24938 detected invalid prediction
# 24939 detected invalid prediction
# 24940 detected invalid prediction
# 24941 detected invalid prediction
# 24942 detected invalid prediction
# 24943 detected invalid prediction
# 24944 detected invalid prediction
# 24945 detected invalid prediction
# 24946 detected invalid prediction
# 24947 detected invalid prediction
# 24948 detected invalid prediction
# 24949 detected invalid prediction
# 24950 detected invalid prediction
# 24951 detected invalid prediction
# 24952 detected invalid prediction
# 24953 detected invalid prediction
# 24954 detected invalid prediction
# 24955 detected invalid prediction
# 24956 detected invalid prediction
# 24957 detected invalid prediction
# 24958 detected invalid prediction
# 24959 detected invalid prediction
# 24960 detected invalid prediction
# 24961 detected invalid prediction
# 24962 detected invalid prediction
# 24963 detected invalid prediction
# 24964 detected invalid prediction
# 24965 detected invalid prediction
# 24966 detected invalid prediction
# 24967 detected invalid prediction
# 24968 detected invalid prediction
# 24969 detected invalid prediction
# 24970 detected invalid prediction
# 24971 detected invalid prediction
# 24972 detected invalid prediction
# 24973 detected invalid prediction
# 24974 detected invalid prediction
# 24975 detected invalid prediction
# 24976 detected invalid prediction
# 24977 detected invalid prediction
# 24978 detected invalid prediction
# 24979 detected invalid prediction
# 24980 detected invalid prediction
# 24981 detected invalid prediction
# 24982 detected invalid prediction
# 24983 detected invalid prediction
# 24984 detected invalid prediction
# 24985 detected invalid prediction
# 24986 detected invalid prediction
# 24987 detected invalid prediction
# 24988 detected invalid prediction
# 24989 detected invalid prediction
# 24990 detected invalid prediction
# 24991 detected invalid prediction
# 24992 detected invalid prediction
# 24993 detected invalid prediction
# 24994 detected invalid prediction
# 24995 detected invalid prediction
# 24996 detected invalid prediction
# 24997 detected invalid prediction
# 24998 detected invalid prediction
# 24999 detected invalid prediction

# %% [markdown]
# This great is great! Our model hasn't generated any invalid prediction. Let's calculate accuarcy and other metrics

# %%
metrics.accuracy_score(targets, outputs)
# Out:
# 0.0

# %%
print(metrics.classification_report(targets, outputs))
# Out:
#                precision    recall  f1-score   support
#
# <pad>negative       0.00      0.00      0.00       0.0
# <pad>positive       0.00      0.00      0.00       0.0
#  negative</s>       0.00      0.00      0.00   12500.0
#  positive</s>       0.00      0.00      0.00   12500.0
#
#      accuracy                           0.00   25000.0
#     macro avg       0.00      0.00      0.00   25000.0
#  weighted avg       0.00      0.00      0.00   25000.0
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/asebaq/dev/Generative-Models/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
